# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Read-pathbank-data" data-toc-modified-id="Read-pathbank-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Read pathbank data</a></span><ul class="toc-item"><li><span><a href="#Read-Pathbank-Pathway-metadata" data-toc-modified-id="Read-Pathbank-Pathway-metadata-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Read Pathbank Pathway metadata</a></span></li><li><span><a href="#Generate-species-pathway-ID" data-toc-modified-id="Generate-species-pathway-ID-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Generate species pathway ID</a></span></li><li><span><a href="#Generate-human-pathway-graph" data-toc-modified-id="Generate-human-pathway-graph-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Generate human pathway graph</a></span><ul class="toc-item"><li><span><a href="#Read-human-pathway" data-toc-modified-id="Read-human-pathway-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Read human pathway</a></span></li><li><span><a href="#Analysis-of-protein-classes-and-metabolite-types" data-toc-modified-id="Analysis-of-protein-classes-and-metabolite-types-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Analysis of protein classes and metabolite types</a></span></li><li><span><a href="#Generate-fingerprint-for-metabolite-ID" data-toc-modified-id="Generate-fingerprint-for-metabolite-ID-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Generate fingerprint for metabolite ID</a></span></li><li><span><a href="#Generate-protein-vectors-for-all-uniport-ID" data-toc-modified-id="Generate-protein-vectors-for-all-uniport-ID-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Generate protein vectors for all uniport ID</a></span></li><li><span><a href="#Generate-features-for-graph" data-toc-modified-id="Generate-features-for-graph-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>Generate features for graph</a></span></li><li><span><a href="#Unsupervised-learning-of-embedded-features" data-toc-modified-id="Unsupervised-learning-of-embedded-features-1.3.6"><span class="toc-item-num">1.3.6&nbsp;&nbsp;</span>Unsupervised learning of embedded features</a></span></li><li><span><a href="#PCA-dimensionality-reduction" data-toc-modified-id="PCA-dimensionality-reduction-1.3.7"><span class="toc-item-num">1.3.7&nbsp;&nbsp;</span>PCA dimensionality reduction</a></span></li></ul></li></ul></li><li><span><a href="#Read-real-world-data" data-toc-modified-id="Read-real-world-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Read real world data</a></span><ul class="toc-item"><li><span><a href="#Get-metabolite-compound-id" data-toc-modified-id="Get-metabolite-compound-id-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Get metabolite compound id</a></span></li></ul></li><li><span><a href="#Spectral-clustering" data-toc-modified-id="Spectral-clustering-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Spectral clustering</a></span></li><li><span><a href="#Baselines" data-toc-modified-id="Baselines-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Baselines</a></span><ul class="toc-item"><li><span><a href="#Adamic-Ada" data-toc-modified-id="Adamic-Ada-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Adamic-Ada</a></span></li><li><span><a href="#Jaccard-Coefficient" data-toc-modified-id="Jaccard-Coefficient-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Jaccard Coefficient</a></span></li><li><span><a href="#Preferential-Attachment" data-toc-modified-id="Preferential-Attachment-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Preferential Attachment</a></span></li></ul></li><li><span><a href="#Graph-Vae-(with-feature)" data-toc-modified-id="Graph-Vae-(with-feature)-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Graph Vae (with feature)</a></span><ul class="toc-item"><li><span><a href="#Read-in-Graph-Data" data-toc-modified-id="Read-in-Graph-Data-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Read in Graph Data</a></span></li><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Data Preprocessing</a></span></li><li><span><a href="#Initialize-VAE-Model" data-toc-modified-id="Initialize-VAE-Model-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Initialize VAE Model</a></span></li><li><span><a href="#Train-and-Evaluate-VAE-Model" data-toc-modified-id="Train-and-Evaluate-VAE-Model-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Train and Evaluate VAE Model</a></span></li></ul></li><li><span><a href="#Graph-Vae-(without-feature)" data-toc-modified-id="Graph-Vae-(without-feature)-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Graph Vae (without feature)</a></span><ul class="toc-item"><li><span><a href="#Read-in-Graph-Data" data-toc-modified-id="Read-in-Graph-Data-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Read in Graph Data</a></span></li><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Data Preprocessing</a></span></li><li><span><a href="#Initialize-VAE-Model" data-toc-modified-id="Initialize-VAE-Model-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Initialize VAE Model</a></span></li><li><span><a href="#Train-and-Evaluate-VAE-Model" data-toc-modified-id="Train-and-Evaluate-VAE-Model-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Train and Evaluate VAE Model</a></span></li></ul></li><li><span><a href="#Node2vec" data-toc-modified-id="Node2vec-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Node2vec</a></span><ul class="toc-item"><li><span><a href="#Train-node2vec-(Learn-Node-Embeddings)" data-toc-modified-id="Train-node2vec-(Learn-Node-Embeddings)-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Train node2vec (Learn Node Embeddings)</a></span></li><li><span><a href="#Create-Edge-Embeddings" data-toc-modified-id="Create-Edge-Embeddings-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Create Edge Embeddings</a></span></li><li><span><a href="#Evaluate-Edge-Embeddings" data-toc-modified-id="Evaluate-Edge-Embeddings-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Evaluate Edge Embeddings</a></span></li></ul></li><li><span><a href="#Visualization-of-all-ROC-curve" data-toc-modified-id="Visualization-of-all-ROC-curve-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Visualization of all ROC curve</a></span></li></ul></div>

# %% [markdown]
# **Run the notebook in conda tf env** <br>
# **Conda activate tf**

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import scipy.sparse as sp
import seaborn as sns
# from node2vec import Node2Vec
from sklearn.metrics import roc_curve, auc, precision_recall_curve, f1_score
from pathlib import Path
import pickle
import glob

# %%
from __future__ import division
from __future__ import print_function
import scipy.sparse as sp
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score
import time
import os
os.environ['CUDA_VISIBLE_DEVICES'] = ""

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.set_random_seed(0)
# Out:
# WARNING:tensorflow:From /Users/chengwang/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
from vgae.optimizer import OptimizerAE, OptimizerVAE
from vgae.model import GCNModelVAE, GCNModelAE
from vgae.preprocessing import preprocess_graph, construct_feed_dict, sparse_to_tuple, mask_test_edges_seed

# %%
import scipy.sparse as sp
import scipy.stats as scs

# %%
from functools import reduce

# %% [markdown]
# # Read MPI data

# %% [markdown]
# ## Read human MPI Network

# %%
## Characteristics of the training dataset
# Get nodes index 
def get_nodes_feats(edges,node_feats):
    num_samples = edges.shape[0]
    edges_nodes = list(edges.reshape(-1).copy())
    edges_nodes = list(set(edges_nodes))
    node_feats_edge = node_feats.loc[edges_nodes].copy()
    size_of_mets = np.mean(node_feats_edge[node_feats_edge['class']=='metabolite']['length'].values)
    size_of_protein = np.mean(node_feats_edge[node_feats_edge['class']=='protein']['length'].values)
    feats_metabolites = node_feats_edge[node_feats_edge['class']=='metabolite']['features'].to_numpy()
    feats_metabolites = np.stack(feats_metabolites, axis=0)
    feats_protein = node_feats_edge[node_feats_edge['class']=='protein']['features'].to_numpy()
    feats_protein = np.stack(feats_protein, axis=0)
    num_samples,int(size_of_mets),int(size_of_protein)
    return num_samples,int(size_of_mets),int(size_of_protein),feats_metabolites,feats_protein,node_feats_edge
def get_edge_feats(edges,node_feats):
    feats_edges = []
    for edge in edges:
        t = node_feats.loc[list(edge)].copy()
        t = t.sort_values(by=['class'])
        edge_f = t['features'].to_numpy()
        edge_f = np.stack(edge_f, axis=0)
        edge_f = edge_f.reshape(-1)
        feats_edges.append(edge_f)
    return np.array(feats_edges)
def get_train_test_similarity(train_data,test_data):
    s1 = train_data.shape[0]
    s2 = test_data.shape[0]
    result = []
    for i in range(s1):
        for j in range(s2):
            sta, p_ = scs.pearsonr(train_data[i], test_data[j])
            result.append(abs(sta))
    result = np.array(result)
    avg_score = np.mean(result)
    std_score = np.std(result)
    return avg_score,std_score
def get_characteristic_fold(train_edges,val_edges,test_edges,node_feats):
    train_s1,train_s2,train_s3,train_t2,train_t3,train_t4 = get_nodes_feats(train_edges,node_feats)
    val_s1,val_s2,val_s3,val_t2,val_t3,val_t4 = get_nodes_feats(val_edges,node_feats)
    test_s1,test_s2,test_s3,test_t2,test_t3,test_t4 = get_nodes_feats(test_edges,node_feats)
    train_edges_feats = get_edge_feats(train_edges,node_feats)
    test_edges_feats = get_edge_feats(test_edges,node_feats)
    mets_avg,mets_std = get_train_test_similarity(train_t2, test_t2)
    protn_avg,protn_std = get_train_test_similarity(train_t3, test_t3)
    edge_avg, edge_std = get_train_test_similarity(train_edges_feats,test_edges_feats)
    result = [train_s1,train_s2,train_s3,val_s1,val_s2,val_s3,test_s1,test_s2,test_s3,mets_avg,mets_std,protn_avg,protn_std,edge_avg,edge_std]
    return result

# %%
train_s1,train_s2,train_s3,train_t2,train_t3,train_t4 = get_nodes_feats(train_edges,node_feats)
test_s1,test_s2,test_s3,test_t2,test_t3,test_t4 = get_nodes_feats(test_edges,node_feats)

# %%
train_edges_feats = get_edge_feats(train_edges,node_feats)
val_edges_feats = get_edge_feats(val_edges,node_feats)
test_edges_feats = get_edge_feats(test_edges,node_feats)

# %%
mets_avg,mets_std = get_train_test_similarity(train_t2, test_t2)

# %%
train_t2.shape
# Out:
# (1261, 1024)

# %%
val_edges_feats.shape
# Out:
# (578, 2048)

# %%
edge_avg, edge_std = get_train_test_similarity(val_edges_feats,test_edges_feats)

# %%
edge_std
# Out:
# 0.1652619517498665

# %%
species = ['Homo sapiens','Mus musculus','Rattus norvegicus','Escherichia coli','Bos taurus','Pseudomonas aeruginosa',
'Arabidopsis thaliana','Saccharomyces cerevisiae','Drosophila melanogaster','Caenorhabditis elegans']
seed_number = [12345, 22345, 32345, 42345, 52345]
result_charc = pd.DataFrame(columns=['organism','seed','sample_train','atom_train_mets','atom_train_protn','sample_val','atom_val_mets','atom_val_protn','sample_test','atom_test_mets','atom_test_protn','sim_mets','sim_mets_std','sim_protn','sim_protn_std','sim_edge','sim_edge_std'])
index = 0
for spcs in species:
    for seed_num in seed_number:
        row = [[]]*len(list(result_charc))
        mpi_file_name = './features/mpi_network/'+'mpi_'+str(spcs).replace(' ','_')+'.pkl'
        df_file_name = './features/mpi_features/'+'feature_df_'+str(spcs).replace(' ','_')+'.pkl'
        g = pickle.load(open(mpi_file_name, "rb" ))
        node_feats = pickle.load(open(df_file_name, "rb" ))
        features = np.stack(node_feats['features'].values, axis=0)
        adj = nx.adjacency_matrix(g,nodelist=node_feats['node'].tolist())
        adj_train, train_edges, train_edges_false, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges_seed(adj, test_frac=.1, val_frac=.1,seed=seed_num)
        characteristic_data = get_characteristic_fold(train_edges,val_edges,test_edges,node_feats)
        row[:2] = [spcs,seed_num]
        row[2:] = characteristic_data
        result_charc.loc[index,:] = row
        index += 1
        print(seed_num,spcs)
# Out:
# 12345 Homo sapiens
# 22345 Homo sapiens
# 32345 Homo sapiens
# 42345 Homo sapiens
# 52345 Homo sapiens
# 12345 Mus musculus
# 22345 Mus musculus
# 32345 Mus musculus
# 42345 Mus musculus
# 52345 Mus musculus
# 12345 Rattus norvegicus
# 22345 Rattus norvegicus
# 32345 Rattus norvegicus
# 42345 Rattus norvegicus
# 52345 Rattus norvegicus
# 12345 Escherichia coli
# 22345 Escherichia coli
# 32345 Escherichia coli
# 42345 Escherichia coli
# 52345 Escherichia coli
# 12345 Bos taurus
# 22345 Bos taurus
# 32345 Bos taurus
# 42345 Bos taurus
# 52345 Bos taurus
# 12345 Pseudomonas aeruginosa
# 22345 Pseudomonas aeruginosa
# 32345 Pseudomonas aeruginosa
# 42345 Pseudomonas aeruginosa
# 52345 Pseudomonas aeruginosa
# 12345 Arabidopsis thaliana
# 22345 Arabidopsis thaliana
# 32345 Arabidopsis thaliana
# 42345 Arabidopsis thaliana
# 52345 Arabidopsis thaliana
# 12345 Saccharomyces cerevisiae
# 22345 Saccharomyces cerevisiae
# 32345 Saccharomyces cerevisiae
# 42345 Saccharomyces cerevisiae
# ...

# %%
result_charc.head()
# Out:
#        organism   seed sample_train atom_train_mets atom_train_protn  \
# 0  Homo sapiens  12345         4629              24              499
# 1  Homo sapiens  22345         4629              24              499
# 2  Homo sapiens  32345         4629              24              499
# 3  Homo sapiens  42345         4629              24              499
# 4  Homo sapiens  52345         4629              24              499
#
#   sample_val atom_val_mets atom_val_protn sample_test atom_test_mets  \
# 0        578            24            503         578             24
# 1        578            24            534         578             25
# 2        578            24            538         578             25
# 3        578            24            536         578             25
# 4        578            23            521         578             23
#
#   atom_test_protn  sim_mets sim_mets_std sim_protn sim_protn_std  sim_edge  \
# ...

# %%
for i in list(result_charc)[2:]:
    t = '%.3f' % np.mean(result_charc[i].values)
    print(i,t)
# Out:
# sample_train 2874.500
# atom_train_mets 24.500
# atom_train_protn 435.600
# sample_val 358.700
# atom_val_mets 23.660
# atom_val_protn 446.640
# sample_test 358.700
# atom_test_mets 24.120
# atom_test_protn 442.020
# sim_mets 0.192
# sim_mets_std 0.149
# sim_protn 0.447
# sim_protn_std 0.215
# sim_edge 0.258
# sim_edge_std 0.196

# %%
result_charc.to_csv('./features/characteristic_data.csv',index=False)

# %% [markdown]
# # VGAE (with feature)

# %% [markdown]
# ## Data Preprocessing

# %%
# Convert features from normal matrix --> sparse matrix --> tuple
# features_tuple contains: (list of matrix coordinates, list of values, matrix dimensions)
features = np.stack(node_feats['features'].values, axis=0)
adj = nx.adjacency_matrix(g,nodelist=node_feats['node'].tolist())

# %% [markdown]
# ## Five fold create data with different seeds,12345, 22345, 32345, 42345, 52345.

# %%
np.random.seed(0) # IMPORTANT: guarantees consistent train/test splits
adj_train, train_edges, train_edges_false, val_edges, val_edges_false, \
    test_edges, test_edges_false = mask_test_edges_seed(adj, test_frac=.1, val_frac=.1,seed=12345)

# %% [markdown]
# ## Initialize VGAE Model

# %%
# Calculate ROC AUC
def get_roc_score_vgae(edges_pos, edges_neg, pos_weight, norm, emb=None):
    if emb is None:
        feed_dict.update({placeholders['dropout']: 0})
        emb = sess.run(model.z_mean, feed_dict=feed_dict)

    def sigmoid(x):
        return 1 / (1 + np.exp(-x))

    # Predict on test set of edges
    adj_rec = np.dot(emb, emb.T)
    preds_pos = []
    pos = []
    for e in edges_pos:
        preds_pos.append(sigmoid(adj_rec[e[0], e[1]])) # predicted score for given edge
        pos.append(adj_orig[e[0], e[1]]) # actual value (1)

    preds_neg = []
    neg = []
    for e in edges_neg:
        preds_neg.append(sigmoid(adj_rec[e[0], e[1]])) # predicted score for given edge
        neg.append(adj_orig[e[0], e[1]]) # actual value (0)

    preds_all = np.hstack([preds_pos, preds_neg])
    labels_all = np.hstack([np.ones(len(preds_pos)), np.zeros(len(preds_neg))])
    roc_score = roc_auc_score(labels_all, preds_all)
    fpr, tpr, _ = roc_curve(labels_all, preds_all)
    precision, recall, _ = precision_recall_curve(labels_all, preds_all)
    pr_score = auc(recall, precision)
    ap_score = average_precision_score(labels_all, preds_all)
    
    # val_loss = norm * tf.reduce_mean(tf.nn.weighted_cross_entropy_with_logits(labels=tf.constant(labels_all), logits=tf.constant(preds_all), pos_weight=pos_weight))
    # val_loss = tf.keras.backend.eval(val_loss)

    return roc_score, ap_score, fpr, tpr, pr_score, precision, recall

# %% [markdown]
# ## Train and Evaluate VGAE Model

# %%
def vgae_feats_train(features,adj,adj_train,train_edges, train_edges_false,val_edges, val_edges_false, test_edges, test_edges_false):
    x = sp.lil_matrix(features)
    features_tuple = sparse_to_tuple(x)
    features_shape = features_tuple[2]
    # Get graph attributes (to feed into model)
    num_nodes = adj.shape[0] # number of nodes in adjacency matrix
    num_features = features_shape[1] # number of features (columsn of features matrix)
    features_nonzero = features_tuple[1].shape[0] # number of non-zero entries in features matrix (or length of values list)
    # Store original adjacency matrix (without diagonal entries) for later
    adj_orig = adj
    adj_orig = adj_orig - sp.dia_matrix((adj_orig.diagonal()[np.newaxis, :], [0]), shape=adj_orig.shape)
    adj_orig.eliminate_zeros()
    # Normalize adjacency matrix
    adj_norm = preprocess_graph(adj_train)
    # Add in diagonals
    adj_label = adj_train + sp.eye(adj_train.shape[0])
    adj_label = sparse_to_tuple(adj_label)

    cost_val = []
    acc_val = []
    val_roc_score = []
    train_loss_log = []
    val_loss_log = []
    # Define hyperparameters
    LEARNING_RATE = 0.005
    EPOCHS = 1000
    HIDDEN1_DIM = 32
    HIDDEN2_DIM = 16
    DROPOUT = 0.1
    # Define placeholders
    placeholders = {
        'features': tf.sparse_placeholder(tf.float32),
        'adj': tf.sparse_placeholder(tf.float32),
        'adj_orig': tf.sparse_placeholder(tf.float32),
        'dropout': tf.placeholder_with_default(0., shape=())
    }

    # How much to weigh positive examples (true edges) in cost print_function
    # Want to weigh less-frequent classes higher, so as to prevent model output bias
    # pos_weight = (num. negative samples / (num. positive samples)
    pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()

    # normalize (scale) average weighted cost
    norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0] - adj.sum()) * 2)

    # Create VAE model
    model = GCNModelVAE(placeholders, num_features, num_nodes, features_nonzero, HIDDEN1_DIM, HIDDEN2_DIM)

    opt = OptimizerVAE(preds=model.reconstructions,
                            labels=tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                        validate_indices=False), [-1]),
                            model=model, num_nodes=num_nodes,
                            pos_weight=pos_weight,
                            norm=norm,
                            learning_rate=LEARNING_RATE)

    # Initialize session
    sess = tf.Session()
    sess.run(tf.global_variables_initializer())

    # Train model
    for epoch in range(EPOCHS):

        t = time.time()
        # Construct feed dictionary
        feed_dict = construct_feed_dict(adj_norm, adj_label, features_tuple, placeholders)
        feed_dict.update({placeholders['dropout']: DROPOUT})
        # Run single weight update
        outs = sess.run([opt.opt_op, opt.cost, opt.accuracy], feed_dict=feed_dict)
        
        # Compute average loss
        avg_cost = outs[1]
        avg_accuracy = outs[2]
        roc_curr, ap_curr, fpr, tpr, pr_score, precision, recall, train_loss_epoch = get_roc_score_vgae(train_edges, train_edges_false, pos_weight, norm)
        train_loss_log.append(train_loss_epoch)

        # Evaluate predictions
        roc_curr, ap_curr, fpr, tpr, pr_score, precision, recall, val_loss_epoch = get_roc_score_vgae(val_edges, val_edges_false, pos_weight, norm)
        val_roc_score.append(roc_curr)
        val_loss_log.append(val_loss_epoch)
        
        if (epoch+1)%50 == 0:
        # Print results for this epoch
            print("Epoch:", '%04d' % (epoch + 1), "train_loss=", "{:.5f}".format(avg_cost),
                "train_acc=", "{:.5f}".format(avg_accuracy), "val_roc=", "{:.5f}".format(val_roc_score[-1]),
                "val_ap=", "{:.5f}".format(ap_curr),
                "time=", "{:.5f}".format(time.time() - t))

    print("Optimization Finished!")

    # Print final results
    feature_roc_score, feature_ap_score, feature_fpr, feature_tpr, feature_pr_score, feature_prcs, feature_rcal, test_loss = get_roc_score(test_edges, test_edges_false, pos_weight, norm)
    result = [feature_roc_score, feature_ap_score, feature_fpr, feature_tpr, feature_pr_score, feature_prcs, feature_rcal, test_loss]
    print('Test ROC score: ' + str(feature_roc_score))
    print('Test AP score: ' + str(feature_ap_score))
    return result

# %%
sns.set_style('ticks')

# %%
plt.figure(figsize = (10,10))
lw = 2
plt.plot(range(len(train_loss_log)), train_loss_log, lw=lw, color='#0070c0', label='Training')
plt.plot(range(len(val_loss_log)), val_loss_log, lw=lw, color='#bf0001',label='Validation')
plt.xlim([0.0, 1000])
plt.ylim([36, 50])
plt.xlabel('Epoch',fontsize = 20)
plt.ylabel('Loss',fontsize = 20)
plt.legend(loc="upper right")
plt.legend(fontsize=20)
plt.savefig("./human_training_loss.pdf")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-fe95a27b22e1> in <module>
#       1 plt.figure(figsize = (10,10))
#       2 lw = 2
# ----> 3 plt.plot(range(len(train_loss_log)), train_loss_log, lw=lw, color='#0070c0', label='Training')
#       4 plt.plot(range(len(val_loss_log)), val_loss_log, lw=lw, color='#bf0001',label='Validation')
#       5 plt.xlim([0.0, 1000])
#
# NameError: name 'train_loss_log' is not defined

# %%
plt.plot(feature_fpr, feature_tpr, color='#bf0001', label='VGAE + Structure')
plt.show()

# %% [markdown]
# ## Obtain confusion matrix

# %%
def vae_pred(test,emb=None):
    if emb is None:
        feed_dict.update({placeholders['dropout']: 0})
        emb = sess.run(model.z_mean, feed_dict=feed_dict)
    
    def sigmoid(x):
        return 1 / (1 + np.exp(-x))

    # Predict on test set of edges
    adj_rec = np.dot(emb, emb.T)
    preds_pos = []
    pos = []
    for e in test:
        preds_pos.append(sigmoid(adj_rec[e[0], e[1]])) # predicted score for given edge
        pos.append(adj_orig[e[0], e[1]]) # actual value (1)
    return np.array(preds_pos),np.array(pos)

# %%
true_test_pred, test_pos = vae_pred(test_edges)
false_test_pred, test_neg = vae_pred(test_edges_false)

# %%
cutoff = 0.67

# %%
test_TP = true_test_pred[np.where(true_test_pred>=cutoff)]
test_TN = false_test_pred[np.where(false_test_pred<cutoff)]
test_FN = true_test_pred[np.where(true_test_pred<cutoff)]
test_FP = false_test_pred[np.where(false_test_pred>=cutoff)]

# %%
N = len(test_TP)+len(test_FP)

# %%
test_TPR = len(test_TP)/(len(test_TP)+len(test_FN))
test_FPR = len(test_FP)/(len(test_FP)+len(test_TN))
print('TPR: %.3f' % test_TPR)
print('FPR: %.3f' % test_FPR)

# %%
test_Precision = len(test_TP)/(len(test_TP)+len(test_FN))
test_Recall = len(test_TP)/(len(test_TP)+len(test_FP))
print('Precision: %.3f' % test_Precision)
print('Recall: %.3f' % test_Recall)

# %%
plt.figure(figsize = (12,10))
data = np.array([[len(test_TP),len(test_FN)],[len(test_FP),len(test_TN)]])
df_cm = pd.DataFrame(data, columns=[['Positive','Negative']], index = [['Positive','Negative']])
# sns.set(font_scale=1.4)#for label size
sns.heatmap(df_cm, cmap="Blues", annot=True,annot_kws={"size": 20},fmt='g')# font size
plt.xlabel('Predicted',fontsize=20)
plt.ylabel('True',fontsize=20)
plt.savefig("./human_confusion_matrix.pdf")
plt.show()

# %% [markdown]
# # Other graph-based models

# %% [markdown]
# # Spectral clustering

# %% [markdown]
# ---
# Spectral clustering for link prediction:
# 1. Compute eigendecomposition of graph Laplacian
# 2. Take top K eigenvectors --> node embedding vectors (Z)
# 3. Edge scores = sigmoid(Z * Z^T)
# 3. Test scores these scores against actual edge values (ROC AUC, AP)
#
# Scikit-learn documentation: http://scikit-learn.org/stable/modules/generated/sklearn.manifold.spectral_embedding.html

# %%
from sklearn.manifold import spectral_embedding

# %%
def get_roc_score(edges_pos, edges_neg, embeddings):
    score_matrix = np.dot(embeddings, embeddings.T)
    
    def sigmoid(x):
        return 1 / (1 + np.exp(-x))
    
    # Store positive edge predictions, actual values
    preds_pos = []
    pos = []
    for edge in edges_pos:
        preds_pos.append(sigmoid(score_matrix[edge[0], edge[1]])) # predicted score
        pos.append(adj_sparse[edge[0], edge[1]]) # actual value (1 for positive)
        
    # Store negative edge predictions, actual values
    preds_neg = []
    neg = []
    for edge in edges_neg:
        preds_neg.append(sigmoid(score_matrix[edge[0], edge[1]])) # predicted score
        neg.append(adj_sparse[edge[0], edge[1]]) # actual value (0 for negative)
        
    # Calculate scores

    preds_all = np.hstack([preds_pos, preds_neg]) # changed the order
    labels_all = np.hstack([np.ones(len(preds_pos)), np.zeros(len(preds_neg))])
    roc_score = roc_auc_score(labels_all, preds_all)
    fpr, tpr, _ = roc_curve(labels_all, preds_all)
    precision, recall, _ = precision_recall_curve(labels_all, preds_all)
    pr_score = auc(recall, precision)
    ap_score = average_precision_score(labels_all, preds_all)
    if roc_score < 0.5 or ap_score < 0.5:
        preds_all = np.hstack([preds_neg, preds_pos]) # changed the order
        labels_all = np.hstack([np.ones(len(preds_neg)), np.zeros(len(preds_pos))])
        roc_score = roc_auc_score(labels_all, preds_all)
        fpr, tpr, _ = roc_curve(labels_all, preds_all)
        precision, recall, _ = precision_recall_curve(labels_all, preds_all)
        pr_score = auc(recall, precision)
        ap_score = average_precision_score(labels_all, preds_all)   
    return roc_score, ap_score, fpr, tpr, pr_score, precision, recall

# %%
# def specluster_pred(test,embeddings):
#     score_matrix = np.dot(embeddings, embeddings.T)
#     def sigmoid(x):
#         return 1 / (1 + np.exp(-x))
    
#     # Store positive edge predictions, actual values
#     preds_pos = []
#     pos = []
#     for edge in test:
#         preds_pos.append(sigmoid(score_matrix[edge[0], edge[1]])) # predicted score
#         pos.append(adj_sparse[edge[0], edge[1]]) # actual value (1 for positive)
#     return preds_pos,pos

# %%
def spectral_clustering_mpi(adj_train, test_edges, test_edges_false):
    # Get spectral embeddings (16-dim)
    emb = spectral_embedding(adj_train, n_components=100, random_state=0)
    # Calculate ROC AUC and Average Precision
    sc_roc, sc_ap, sc_fpr, sc_tpr, pr_score, sc_prcs, sc_rcal = get_roc_score(test_edges, test_edges_false, emb)
    print ('Spectral Clustering Test ROC score: ', str(sc_roc))
    print ('Spectral Clustering Test AP score: ', str(sc_ap))
    print ('Spectral Clustering Test precision-recall score: ', str(pr_score))
    result = [sc_roc, sc_ap, sc_fpr, sc_tpr, pr_score, sc_prcs, sc_rcal]
    return result

# %% [markdown]
# # Baselines

# %% [markdown]
# ROC AUC and Average Precision using the following baselind
# 1. Adamic-Adar
# 2. Jaccard Coefficient
# 3. Preferential Attachment

# %% [markdown]
# ## Adamic-Ada

# %%
# Compute Adamic-Adar indexes from g_train
def Adamic_Ada_mpi(adj_sparse, g_train, test_edges, test_edges_false):
    aa_matrix = np.zeros(adj_sparse.shape)
    for u, v, p in nx.adamic_adar_index(g_train): # (u, v) = node indices, p = Adamic-Adar index
        aa_matrix[u][v] = p
        aa_matrix[v][u] = p # make sure it's symmetric
    # Normalize array
    aa_matrix = aa_matrix / aa_matrix.max()
    # Calculate ROC AUC and Average Precision
    aa_roc, aa_ap, aa_fpr, aa_tpr, aa_pr_score, aa_prcs, aa_rcal = get_roc_score(test_edges, test_edges_false, aa_matrix)
    print ('Adamic-Adar Test ROC score: ', str(aa_roc))
    print ('Adamic-Adar Test AP score: ', str(aa_ap))
    result = [aa_roc, aa_ap, aa_fpr, aa_tpr, aa_pr_score, aa_prcs, aa_rcal]
    return result

# %% [markdown]
# ## Jaccard Coefficient

# %%
def Jaccard_mpi(adj_sparse, g_train, test_edges, test_edges_false):
    # Compute Jaccard Coefficients from g_train
    jc_matrix = np.zeros(adj_sparse.shape)
    for u, v, p in nx.jaccard_coefficient(g_train): # (u, v) = node indices, p = Jaccard coefficient
        jc_matrix[u][v] = p
        jc_matrix[v][u] = p # make sure it's symmetric
        
    # Normalize array
    jc_matrix = jc_matrix / jc_matrix.max()
    # Calculate ROC AUC and Average Precision
    jc_roc, jc_ap, jc_fpr, jc_tpr, jc_pr_score, jc_prcs, jc_rcal = get_roc_score(test_edges, test_edges_false, jc_matrix)

    print ('Jaccard Coefficient Test ROC score: ', str(jc_roc))
    print ('Jaccard Coefficient Test AP score: ', str(jc_ap))
    result = [jc_roc, jc_ap, jc_fpr, jc_tpr, jc_pr_score, jc_prcs, jc_rcal]
    return result

# %% [markdown]
# ## Preferential Attachment

# %%
def pa_mpi(adj_sparse, g_train, test_edges, test_edges_false):
    # Calculate, store Adamic-Index scores in array
    pa_matrix = np.zeros(adj_sparse.shape)
    for u, v, p in nx.preferential_attachment(g_train): # (u, v) = node indices, p = Jaccard coefficient
        pa_matrix[u][v] = p
        pa_matrix[v][u] = p # make sure it's symmetric
    # Normalize array
    pa_matrix = pa_matrix / pa_matrix.max()
    # Calculate ROC AUC and Average Precision
    pa_roc, pa_ap, pa_fpr, pa_tpr, pa_pr_score, pa_prcs, pa_rcal = get_roc_score(test_edges, test_edges_false, pa_matrix)
    print ('Preferential Attachment Test ROC score: ', str(pa_roc))
    print ('Preferential Attachment Test AP score: ', str(pa_ap))
    result = [pa_roc, pa_ap, pa_fpr, pa_tpr, pa_pr_score, pa_prcs, pa_rcal]
    return result

# %% [markdown]
# # Node2vec

# %% [markdown]
# ---
# [node2vec](http://snap.stanford.edu/node2vec/) for link prediction:
# 1. Perform train-test split
# 1. Train skip-gram model on random walks within training graph
# 2. Get node embeddings from skip-gram model
# 3. Create bootstrapped edge embeddings by taking the Hadamard product of node embeddings
# 4. Train a logistic regression classifier on these edge embeddings (possible edge --> edge score between 0-1)
# 5. Evaluate these edge embeddings on the validation and test edge sets
#
# node2vec source code: https://github.com/aditya-grover/node2vec

# %% [markdown]
# ## Train node2vec (Learn Node Embeddings)

# %%
import node2vec_lp
import smart_open
smart_open.open = smart_open.smart_open
from gensim.models import word2vec
# Out:
# /Users/chengwang/opt/anaconda3/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# ## Create Edge Embeddings

# %%
# Generate bootstrapped edge embeddings (as is done in node2vec paper)
    # Edge embedding for (v1, v2) = hadamard product of node embeddings for v1, v2
def get_edge_embeddings(emb_matrix,edge_list):
    embs = []
    for edge in edge_list:
        node1 = edge[0]
        node2 = edge[1]
        emb1 = emb_matrix[node1]
        emb2 = emb_matrix[node2]
        edge_emb = np.multiply(emb1, emb2)
        embs.append(edge_emb)
    embs = np.array(embs)
    return embs

# %% [markdown]
# ## Evaluate Edge Embeddings

# %%
# Train logistic regression classifier on train-set edge embeddings
from sklearn.linear_model import LogisticRegression,Perceptron,SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
def novde2vec_mpi(adj_sparse, g_train,train_edges, train_edges_false, test_edges, test_edges_false):
    # node2vec settings
    # NOTE: When p = q = 1, this is equivalent to DeepWalk
    P = 1 # Return hyperparameter
    Q = 1 # In-out hyperparameter
    WINDOW_SIZE = 10 # Context size for optimization
    NUM_WALKS = 10 # Number of walks per source
    WALK_LENGTH = 80 # Length of walk per source
    DIMENSIONS = 128 # Embedding dimension
    DIRECTED = False # Graph directed/undirected
    WORKERS = 8 # Num. parallel workers
    ITER = 1 # SGD epochs
    # Preprocessing, generate walks
    g_n2v = node2vec_lp.Graph(g_train, DIRECTED, P, Q) # create node2vec graph instance
    g_n2v.preprocess_transition_probs()
    walks = g_n2v.simulate_walks(NUM_WALKS, WALK_LENGTH)
    walks_str = []
    for walk in walks:
        t = [str(i) for i in walk]
        walks_str.append(t)
    walks = walks_str
    # walks = [list(map(str, walk) for walk in walks)]
    # # # Train skip-gram model
    model = word2vec.Word2Vec(walks, vector_size=DIMENSIONS, window=WINDOW_SIZE, min_count=0, sg=1, workers=WORKERS, epochs=ITER)
    # # Store embeddings mapping
    emb_mappings = model.wv
    # Create node embeddings matrix (rows = nodes, columns = embedding features)
    emb_list = []
    for node_index in range(0, adj_sparse.shape[0]):
        node_str = str(node_index)
        node_emb = emb_mappings[node_str]
        emb_list.append(node_emb)
    emb_matrix = np.vstack(emb_list)
    # Train-set edge embeddings
    pos_train_edge_embs = get_edge_embeddings(emb_matrix,train_edges)
    neg_train_edge_embs = get_edge_embeddings(emb_matrix,train_edges_false)
    train_edge_embs = np.concatenate([pos_train_edge_embs, neg_train_edge_embs])
    # Create train-set edge labels: 1 = real edge, 0 = false edge
    train_edge_labels = np.concatenate([np.ones(len(train_edges)), np.zeros(len(train_edges_false))])

    # Val-set edge embeddings, labels
    # pos_val_edge_embs = get_edge_embeddings(val_edges)
    # neg_val_edge_embs = get_edge_embeddings(val_edges_false)
    # val_edge_embs = np.concatenate([pos_val_edge_embs, neg_val_edge_embs])
    # val_edge_labels = np.concatenate([np.ones(len(val_edges)), np.zeros(len(val_edges_false))])

    # Test-set edge embeddings, labels
    pos_test_edge_embs = get_edge_embeddings(emb_matrix,test_edges)
    neg_test_edge_embs = get_edge_embeddings(emb_matrix,test_edges_false)
    test_edge_embs = np.concatenate([pos_test_edge_embs, neg_test_edge_embs])
    # Create val-set edge labels: 1 = real edge, 0 = false edge
    test_edge_labels = np.concatenate([np.ones(len(test_edges)), np.zeros(len(test_edges_false))])

    edge_classifier = LogisticRegression(random_state=0)
    edge_classifier.fit(train_edge_embs, train_edge_labels)

    # Predicted edge scores: probability of being of class "1" (real edge)
    # val_preds = edge_classifier.predict_proba(val_edge_embs)[:, 1]
    # val_roc = roc_auc_score(val_edge_labels, val_preds)
    # val_fpr, val_tpr, _ = roc_curve(val_edge_labels, val_preds)
    # val_ap = average_precision_score(val_edge_labels, val_preds)

    # Predicted edge scores: probability of being of class "1" (real edge)
    nv_test_preds = edge_classifier.predict_proba(test_edge_embs)[:, 1]
    nv_test_roc = roc_auc_score(test_edge_labels, nv_test_preds)
    nv_test_fpr, nv_test_tpr, _ = roc_curve(test_edge_labels, nv_test_preds)
    nv_test_ap = average_precision_score(test_edge_labels, nv_test_preds)
    nv_precision, nv_recall, _ = precision_recall_curve(test_edge_labels, nv_test_preds)
    # nv_pr_score = auc(nv_precision, nv_recall)
    # print ('node2vec Validation ROC score: ', str(val_roc))
    # print ('node2vec Validation AP score: ', str(val_ap))
    print ('node2vec Test ROC score: ', str(nv_test_roc))
    print ('node2vec Test AP score: ', str(nv_test_ap))
    result = [nv_test_roc,nv_precision,nv_test_fpr, nv_test_tpr,nv_test_ap,nv_precision, nv_recall]
    return result

# %%
species = ['Homo sapiens','Mus musculus','Rattus norvegicus','Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana','Saccharomyces cerevisiae','Drosophila melanogaster','Caenorhabditis elegans']
seed_number = [12345, 22345, 32345, 42345, 52345, 62345]
index = 0
error_message = []
result = {}
for spcs in species[1:]:
    spcs_temp = {}
    for seed_num in seed_number[:5]:
        mpi_file_name = './features/mpi_network/'+'mpi_'+str(spcs).replace(' ','_')+'.pkl'
        df_file_name = './features/mpi_features/'+'feature_df_'+str(spcs).replace(' ','_')+'.pkl'
        g = pickle.load(open(mpi_file_name, "rb" ))
        node_feats = pickle.load(open(df_file_name, "rb" ))
        adj = nx.adjacency_matrix(g,nodelist=node_feats['node'].tolist())
        adj_train, train_edges, train_edges_false, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges_seed(adj, test_frac=.1, val_frac=.1,seed=seed_num)
        
        adj_sparse = nx.to_scipy_sparse_matrix(g)
        g_train = nx.from_scipy_sparse_matrix(adj_train) # new graph object with only non-hidden edges
        
        try:
            sc_result = spectral_clustering_mpi(adj_train, test_edges, test_edges_false)
            print(sc_result)
        except:
            error = 'sc_'+str(spcs)+'_'+str(seed_num)
            error_message.append(error)
            sc_result = error          
        try:
            aa_result = Adamic_Ada_mpi(adj_sparse, g_train, test_edges, test_edges_false)
        except:
            error = 'aa_'+str(spcs)+'_'+str(seed_num)
            error_message.append(error)
            aa_result = error
        try:
            jc_result = Jaccard_mpi(adj_sparse, g_train, test_edges, test_edges_false)
        except:
            error = 'jc_'+str(spcs)+'_'+str(seed_num)
            error_message.append(error)
            jc_result = error
        try:
            pa_result = pa_mpi(adj_sparse, g_train, test_edges, test_edges_false)
        except:
            error = 'pa_'+str(spcs)+'_'+str(seed_num)
            error_message.append(error)
            pa_result = error
        try:     
            nv_result = novde2vec_mpi(adj_sparse, g_train, train_edges, train_edges_false, test_edges, test_edges_false)
        except:
            error = 'node2vec_'+str(spcs)+'_'+str(seed_num)
            error_message.append(error)
            nv_result = error
        temp = [sc_result,aa_result,jc_result,pa_result,nv_result]
        spcs_temp[seed_num] = temp
    result[spcs] = spcs_temp
pickle.dump(error_message,open('./error_message.pkl','wb'))
pickle.dump(result,open('./non-graph_model-3.pkl','wb'))
print(spcs,seed_num)

# %%
species = ['Homo sapiens','Mus musculus','Rattus norvegicus','Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana','Saccharomyces cerevisiae','Drosophila melanogaster','Caenorhabditis elegans']
seed_number = [12345, 22345, 32345, 42345, 52345, 62345]
index = 0
error_message = []
result = {}
for spcs in species[1:]:
    spcs_temp = {}
    for seed_num in seed_number:
        mpi_file_name = './features/mpi_network/'+'mpi_'+str(spcs).replace(' ','_')+'.pkl'
        df_file_name = './features/mpi_features/'+'feature_df_'+str(spcs).replace(' ','_')+'.pkl'
        g = pickle.load(open(mpi_file_name, "rb" ))
        node_feats = pickle.load(open(df_file_name, "rb" ))
        adj = nx.adjacency_matrix(g,nodelist=node_feats['node'].tolist())
        adj_train, train_edges, train_edges_false, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges_seed(adj, test_frac=.1, val_frac=.1,seed=seed_num)
        
        adj_sparse = nx.to_scipy_sparse_matrix(g)
        g_train = nx.from_scipy_sparse_matrix(adj_train) # new graph object with only non-hidden edges
        print(spcs,seed_num)       
        try:
            aa_result = Adamic_Ada_mpi(adj_sparse, g_train, test_edges, test_edges_false)
        except:
            error = 'aa_'+str(spcs)+'_'+str(seed_num)
            error_message.append(error)
            aa_result = error
        # try:
        #     jc_result = Jaccard_mpi(adj_sparse, g_train, test_edges, test_edges_false)
        # except:
        #     error = 'jc_'+str(spcs)+'_'+str(seed_num)
        #     error_message.append(error)
        #     jc_result = error
        temp = [aa_result]
        spcs_temp[seed_num] = temp
    result[spcs] = spcs_temp
    
pickle.dump(error_message,open('./error_message.pkl','wb'))
pickle.dump(result,open('./aa-graph_model-3.pkl','wb'))
# Out:
# Mus musculus 12345
# Adamic-Adar Test ROC score:  0.5096420054274827
# Adamic-Adar Test AP score:  0.5257550831851341
# Mus musculus 22345
# Adamic-Adar Test ROC score:  0.5122940708862147
# Adamic-Adar Test AP score:  0.49875151195465706
# Mus musculus 32345
# Adamic-Adar Test ROC score:  0.5339217674954085
# Adamic-Adar Test AP score:  0.5371374776481365
# Mus musculus 42345
# Adamic-Adar Test ROC score:  0.51263671500233
# Adamic-Adar Test AP score:  0.5211115182406771
# Mus musculus 52345
# Adamic-Adar Test ROC score:  0.506475973794578
# Adamic-Adar Test AP score:  0.499879946638708
# Mus musculus 62345
# Adamic-Adar Test ROC score:  0.5296798333379019
# Adamic-Adar Test AP score:  0.5290930951969395
# Rattus norvegicus 12345
# Adamic-Adar Test ROC score:  0.5618102618701502
# Adamic-Adar Test AP score:  0.5631978107992323
# Rattus norvegicus 22345
# Adamic-Adar Test ROC score:  0.5624731270858501
# Adamic-Adar Test AP score:  0.5729707933813154
# Rattus norvegicus 32345
# ...

# %%
species = ['Homo sapiens','Mus musculus','Rattus norvegicus','Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana','Saccharomyces cerevisiae','Drosophila melanogaster','Caenorhabditis elegans']
seed_number = [12345, 22345, 32345, 42345, 52345]
index = 0
error_message = []
result = {}
for spcs in species:
    spcs_temp = {}
    for seed_num in seed_number:
        mpi_file_name = './features/mpi_network/'+'mpi_'+str(spcs).replace(' ','_')+'.pkl'
        df_file_name = './features/mpi_features/'+'feature_df_'+str(spcs).replace(' ','_')+'.pkl'
        g = pickle.load(open(mpi_file_name, "rb" ))
        node_feats = pickle.load(open(df_file_name, "rb" ))
        adj = nx.adjacency_matrix(g,nodelist=node_feats['node'].tolist())
        adj_train, train_edges, train_edges_false, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges_seed(adj, test_frac=.1, val_frac=.1,seed=seed_num)
        adj_sparse = nx.to_scipy_sparse_matrix(g)
        g_train = nx.from_scipy_sparse_matrix(adj_train) # new graph object with only non-hidden edges
        print(spcs,seed_num) 
        # node2vec settings
        # NOTE: When p = q = 1, this is equivalent to DeepWalk
        P = 1 # Return hyperparameter
        Q = 1 # In-out hyperparameter
        WINDOW_SIZE = 10 # Context size for optimization
        NUM_WALKS = 10 # Number of walks per source
        WALK_LENGTH = 80 # Length of walk per source
        DIMENSIONS = 128 # Embedding dimension
        DIRECTED = False # Graph directed/undirected
        WORKERS = 8 # Num. parallel workers
        ITER = 1 # SGD epochs
        # Preprocessing, generate walks
        g_n2v = node2vec_lp.Graph(g_train, DIRECTED, P, Q) # create node2vec graph instance
        g_n2v.preprocess_transition_probs()
        walks = g_n2v.simulate_walks(NUM_WALKS, WALK_LENGTH)
        walks_str = []
        for walk in walks:
            t = [str(i) for i in walk]
            walks_str.append(t)
        walks = walks_str
        # walks = [list(map(str, walk) for walk in walks)]
        # # # Train skip-gram model
        model = word2vec.Word2Vec(walks, vector_size=DIMENSIONS, window=WINDOW_SIZE, min_count=0, sg=1, workers=WORKERS, epochs=ITER)
        # # Store embeddings mapping
        emb_mappings = model.wv
        # Create node embeddings matrix (rows = nodes, columns = embedding features)
        emb_list = []
        for node_index in range(0, adj_sparse.shape[0]):
            node_str = str(node_index)
            node_emb = emb_mappings[node_str]
            emb_list.append(node_emb)
        emb_matrix = np.vstack(emb_list)
        # Train-set edge embeddings
        pos_train_edge_embs = get_edge_embeddings(emb_matrix,train_edges)
        neg_train_edge_embs = get_edge_embeddings(emb_matrix,train_edges_false)
        train_edge_embs = np.concatenate([pos_train_edge_embs, neg_train_edge_embs])
        # Create train-set edge labels: 1 = real edge, 0 = false edge
        train_edge_labels = np.concatenate([np.ones(len(train_edges)), np.zeros(len(train_edges_false))])
        
        # Test-set edge embeddings, labels
        pos_test_edge_embs = get_edge_embeddings(emb_matrix,test_edges)
        neg_test_edge_embs = get_edge_embeddings(emb_matrix,test_edges_false)
        test_edge_embs = np.concatenate([pos_test_edge_embs, neg_test_edge_embs])
        # Create val-set edge labels: 1 = real edge, 0 = false edge
        test_edge_labels = np.concatenate([np.ones(len(test_edges)), np.zeros(len(test_edges_false))])

        # edge_classifier = LogisticRegression(random_state=0)
        edge_classifier = RandomForestClassifier(random_state=0)
        # edge_classifier = SGDClassifier(loss='log_loss',random_state=0,penalty='l1')
        # edge_classifier = SVC(random_state=0,probability=True)
        # edge_classifier = GradientBoostingClassifier(random_state=0)
        # edge_classifier = MLPClassifier(random_state=0)
        edge_classifier.fit(train_edge_embs, train_edge_labels)
        # Predicted edge scores: probability of being of class "1" (real edge)
        nv_test_preds = edge_classifier.predict_proba(test_edge_embs)[:, 1]
        nv_test_roc = roc_auc_score(test_edge_labels, nv_test_preds)
        nv_test_fpr, nv_test_tpr, _ = roc_curve(test_edge_labels, nv_test_preds)
        nv_test_ap = average_precision_score(test_edge_labels, nv_test_preds)
        nv_precision, nv_recall, _ = precision_recall_curve(test_edge_labels, nv_test_preds)
        print ('node2vec Test ROC score: ', str(nv_test_roc))
        print ('node2vec Test AP score: ', str(nv_test_ap))
        nv_result = [nv_test_roc,nv_precision,nv_test_fpr, nv_test_tpr,nv_test_ap,nv_precision, nv_recall]
        temp = [nv_result]
        spcs_temp[seed_num] = temp
    result[spcs] = spcs_temp
pickle.dump(result,open('./nv-graph_model-rf.pkl','wb'))
# Out:
# Homo sapiens 12345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# node2vec Test ROC score:  0.9037966499443254
# node2vec Test AP score:  0.8966775741597842
# Homo sapiens 22345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# node2vec Test ROC score:  0.8901234420085966
# node2vec Test AP score:  0.8818651256672763
# Homo sapiens 32345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# node2vec Test ROC score:  0.8880805426180242
# node2vec Test AP score:  0.8740410352795183
# Homo sapiens 42345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# node2vec Test ROC score:  0.8837747392871254
# node2vec Test AP score:  0.8808203473269134
# Homo sapiens 52345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# ...

# %%
species = ['Homo sapiens','Mus musculus','Rattus norvegicus','Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana','Saccharomyces cerevisiae','Drosophila melanogaster','Caenorhabditis elegans']
seed_number = [12345, 22345, 32345, 42345, 52345]
index = 0
error_message = []
result = {}
for spcs in species:
    spcs_temp = {}
    for seed_num in seed_number:
        mpi_file_name = './features/mpi_network/'+'mpi_'+str(spcs).replace(' ','_')+'.pkl'
        df_file_name = './features/mpi_features/'+'feature_df_'+str(spcs).replace(' ','_')+'.pkl'
        g = pickle.load(open(mpi_file_name, "rb" ))
        node_feats = pickle.load(open(df_file_name, "rb" ))
        adj = nx.adjacency_matrix(g,nodelist=node_feats['node'].tolist())
        adj_train, train_edges, train_edges_false, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges_seed(adj, test_frac=.1, val_frac=.1,seed=seed_num)
        adj_sparse = nx.to_scipy_sparse_matrix(g)
        g_train = nx.from_scipy_sparse_matrix(adj_train) # new graph object with only non-hidden edges
        print(spcs,seed_num) 
        # node2vec settings
        # NOTE: When p = q = 1, this is equivalent to DeepWalk
        P = 1 # Return hyperparameter
        Q = 1 # In-out hyperparameter
        WINDOW_SIZE = 10 # Context size for optimization
        NUM_WALKS = 10 # Number of walks per source
        WALK_LENGTH = 80 # Length of walk per source
        DIMENSIONS = 128 # Embedding dimension
        DIRECTED = False # Graph directed/undirected
        WORKERS = 8 # Num. parallel workers
        ITER = 1 # SGD epochs
        # Preprocessing, generate walks
        g_n2v = node2vec_lp.Graph(g_train, DIRECTED, P, Q) # create node2vec graph instance
        g_n2v.preprocess_transition_probs()
        walks = g_n2v.simulate_walks(NUM_WALKS, WALK_LENGTH)
        walks_str = []
        for walk in walks:
            t = [str(i) for i in walk]
            walks_str.append(t)
        walks = walks_str
        # walks = [list(map(str, walk) for walk in walks)]
        # # # Train skip-gram model
        model = word2vec.Word2Vec(walks, vector_size=DIMENSIONS, window=WINDOW_SIZE, min_count=0, sg=1, workers=WORKERS, epochs=ITER)
        # # Store embeddings mapping
        emb_mappings = model.wv
        # Create node embeddings matrix (rows = nodes, columns = embedding features)
        emb_list = []
        for node_index in range(0, adj_sparse.shape[0]):
            node_str = str(node_index)
            node_emb = emb_mappings[node_str]
            emb_list.append(node_emb)
        emb_matrix = np.vstack(emb_list)
        # Train-set edge embeddings
        pos_train_edge_embs = get_edge_embeddings(emb_matrix,train_edges)
        neg_train_edge_embs = get_edge_embeddings(emb_matrix,train_edges_false)
        train_edge_embs = np.concatenate([pos_train_edge_embs, neg_train_edge_embs])
        # Create train-set edge labels: 1 = real edge, 0 = false edge
        train_edge_labels = np.concatenate([np.ones(len(train_edges)), np.zeros(len(train_edges_false))])
        
        # Test-set edge embeddings, labels
        pos_test_edge_embs = get_edge_embeddings(emb_matrix,test_edges)
        neg_test_edge_embs = get_edge_embeddings(emb_matrix,test_edges_false)
        test_edge_embs = np.concatenate([pos_test_edge_embs, neg_test_edge_embs])
        # Create val-set edge labels: 1 = real edge, 0 = false edge
        test_edge_labels = np.concatenate([np.ones(len(test_edges)), np.zeros(len(test_edges_false))])

        # edge_classifier = LogisticRegression(random_state=0)
        # edge_classifier = RandomForestClassifier(random_state=0)
        edge_classifier = SGDClassifier(loss='log_loss',random_state=0,penalty='l1')
        # edge_classifier = SVC(random_state=0,probability=True)
        # edge_classifier = GradientBoostingClassifier(random_state=0)
        # edge_classifier = MLPClassifier(random_state=0)
        edge_classifier.fit(train_edge_embs, train_edge_labels)
        # Predicted edge scores: probability of being of class "1" (real edge)
        nv_test_preds = edge_classifier.predict_proba(test_edge_embs)[:, 1]
        nv_test_roc = roc_auc_score(test_edge_labels, nv_test_preds)
        nv_test_fpr, nv_test_tpr, _ = roc_curve(test_edge_labels, nv_test_preds)
        nv_test_ap = average_precision_score(test_edge_labels, nv_test_preds)
        nv_precision, nv_recall, _ = precision_recall_curve(test_edge_labels, nv_test_preds)
        print ('node2vec Test ROC score: ', str(nv_test_roc))
        print ('node2vec Test AP score: ', str(nv_test_ap))
        nv_result = [nv_test_roc,nv_precision,nv_test_fpr, nv_test_tpr,nv_test_ap,nv_precision, nv_recall]
        temp = [nv_result]
        spcs_temp[seed_num] = temp
    result[spcs] = spcs_temp
pickle.dump(result,open('./nv-graph_model-sgd.pkl','wb'))
# Out:
# Homo sapiens 12345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# node2vec Test ROC score:  0.8676081464541852
# node2vec Test AP score:  0.8639707512805342
# Homo sapiens 22345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# node2vec Test ROC score:  0.875091294405
# node2vec Test AP score:  0.8778273582659244
# Homo sapiens 32345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# node2vec Test ROC score:  0.8571167730271428
# node2vec Test AP score:  0.8592430206337998
# Homo sapiens 42345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# node2vec Test ROC score:  0.8569281976987824
# node2vec Test AP score:  0.8501172477158435
# Homo sapiens 52345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# ...

# %%
species = ['Homo sapiens','Mus musculus','Rattus norvegicus','Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana','Saccharomyces cerevisiae','Drosophila melanogaster','Caenorhabditis elegans']
seed_number = [12345, 22345, 32345, 42345, 52345]
index = 0
error_message = []
result = {}
for spcs in species:
    spcs_temp = {}
    for seed_num in seed_number:
        mpi_file_name = './features/mpi_network/'+'mpi_'+str(spcs).replace(' ','_')+'.pkl'
        df_file_name = './features/mpi_features/'+'feature_df_'+str(spcs).replace(' ','_')+'.pkl'
        g = pickle.load(open(mpi_file_name, "rb" ))
        node_feats = pickle.load(open(df_file_name, "rb" ))
        adj = nx.adjacency_matrix(g,nodelist=node_feats['node'].tolist())
        adj_train, train_edges, train_edges_false, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges_seed(adj, test_frac=.1, val_frac=.1,seed=seed_num)
        adj_sparse = nx.to_scipy_sparse_matrix(g)
        g_train = nx.from_scipy_sparse_matrix(adj_train) # new graph object with only non-hidden edges
        print(spcs,seed_num) 
        # node2vec settings
        # NOTE: When p = q = 1, this is equivalent to DeepWalk
        P = 1 # Return hyperparameter
        Q = 1 # In-out hyperparameter
        WINDOW_SIZE = 10 # Context size for optimization
        NUM_WALKS = 10 # Number of walks per source
        WALK_LENGTH = 80 # Length of walk per source
        DIMENSIONS = 128 # Embedding dimension
        DIRECTED = False # Graph directed/undirected
        WORKERS = 8 # Num. parallel workers
        ITER = 1 # SGD epochs
        # Preprocessing, generate walks
        g_n2v = node2vec_lp.Graph(g_train, DIRECTED, P, Q) # create node2vec graph instance
        g_n2v.preprocess_transition_probs()
        walks = g_n2v.simulate_walks(NUM_WALKS, WALK_LENGTH)
        walks_str = []
        for walk in walks:
            t = [str(i) for i in walk]
            walks_str.append(t)
        walks = walks_str
        # walks = [list(map(str, walk) for walk in walks)]
        # # # Train skip-gram model
        model = word2vec.Word2Vec(walks, vector_size=DIMENSIONS, window=WINDOW_SIZE, min_count=0, sg=1, workers=WORKERS, epochs=ITER)
        # # Store embeddings mapping
        emb_mappings = model.wv
        # Create node embeddings matrix (rows = nodes, columns = embedding features)
        emb_list = []
        for node_index in range(0, adj_sparse.shape[0]):
            node_str = str(node_index)
            node_emb = emb_mappings[node_str]
            emb_list.append(node_emb)
        emb_matrix = np.vstack(emb_list)
        # Train-set edge embeddings
        pos_train_edge_embs = get_edge_embeddings(emb_matrix,train_edges)
        neg_train_edge_embs = get_edge_embeddings(emb_matrix,train_edges_false)
        train_edge_embs = np.concatenate([pos_train_edge_embs, neg_train_edge_embs])
        # Create train-set edge labels: 1 = real edge, 0 = false edge
        train_edge_labels = np.concatenate([np.ones(len(train_edges)), np.zeros(len(train_edges_false))])
        
        # Test-set edge embeddings, labels
        pos_test_edge_embs = get_edge_embeddings(emb_matrix,test_edges)
        neg_test_edge_embs = get_edge_embeddings(emb_matrix,test_edges_false)
        test_edge_embs = np.concatenate([pos_test_edge_embs, neg_test_edge_embs])
        # Create val-set edge labels: 1 = real edge, 0 = false edge
        test_edge_labels = np.concatenate([np.ones(len(test_edges)), np.zeros(len(test_edges_false))])

        # edge_classifier = LogisticRegression(random_state=0)
        # edge_classifier = RandomForestClassifier(random_state=0)
        # edge_classifier = SGDClassifier(loss='log_loss',random_state=0,penalty='l1')
        edge_classifier = SVC(random_state=0,probability=True)
        # edge_classifier = GradientBoostingClassifier(random_state=0)
        # edge_classifier = MLPClassifier(random_state=0)
        edge_classifier.fit(train_edge_embs, train_edge_labels)
        # Predicted edge scores: probability of being of class "1" (real edge)
        nv_test_preds = edge_classifier.predict_proba(test_edge_embs)[:, 1]
        nv_test_roc = roc_auc_score(test_edge_labels, nv_test_preds)
        nv_test_fpr, nv_test_tpr, _ = roc_curve(test_edge_labels, nv_test_preds)
        nv_test_ap = average_precision_score(test_edge_labels, nv_test_preds)
        nv_precision, nv_recall, _ = precision_recall_curve(test_edge_labels, nv_test_preds)
        print ('node2vec Test ROC score: ', str(nv_test_roc))
        print ('node2vec Test AP score: ', str(nv_test_ap))
        nv_result = [nv_test_roc,nv_precision,nv_test_fpr, nv_test_tpr,nv_test_ap,nv_precision, nv_recall]
        temp = [nv_result]
        spcs_temp[seed_num] = temp
    result[spcs] = spcs_temp
pickle.dump(result,open('./nv-graph_model-svc.pkl','wb'))
# Out:
# Homo sapiens 12345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# node2vec Test ROC score:  0.8991032195495744
# node2vec Test AP score:  0.8946432072083438
# Homo sapiens 22345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# node2vec Test ROC score:  0.8753636809904096
# node2vec Test AP score:  0.8827526385663859
# Homo sapiens 32345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# node2vec Test ROC score:  0.8932693574071191
# node2vec Test AP score:  0.8971491319732079
# Homo sapiens 42345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# node2vec Test ROC score:  0.8847475485207315
# node2vec Test AP score:  0.8864658073368217
# Homo sapiens 52345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# ...

# %%
species = ['Homo sapiens','Mus musculus','Rattus norvegicus','Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana','Saccharomyces cerevisiae','Drosophila melanogaster','Caenorhabditis elegans']
seed_number = [12345, 22345, 32345, 42345, 52345]
index = 0
error_message = []
result = {}
for spcs in species:
    spcs_temp = {}
    for seed_num in seed_number:
        mpi_file_name = './features/mpi_network/'+'mpi_'+str(spcs).replace(' ','_')+'.pkl'
        df_file_name = './features/mpi_features/'+'feature_df_'+str(spcs).replace(' ','_')+'.pkl'
        g = pickle.load(open(mpi_file_name, "rb" ))
        node_feats = pickle.load(open(df_file_name, "rb" ))
        adj = nx.adjacency_matrix(g,nodelist=node_feats['node'].tolist())
        adj_train, train_edges, train_edges_false, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges_seed(adj, test_frac=.1, val_frac=.1,seed=seed_num)
        adj_sparse = nx.to_scipy_sparse_matrix(g)
        g_train = nx.from_scipy_sparse_matrix(adj_train) # new graph object with only non-hidden edges
        print(spcs,seed_num) 
        # node2vec settings
        # NOTE: When p = q = 1, this is equivalent to DeepWalk
        P = 1 # Return hyperparameter
        Q = 1 # In-out hyperparameter
        WINDOW_SIZE = 10 # Context size for optimization
        NUM_WALKS = 10 # Number of walks per source
        WALK_LENGTH = 80 # Length of walk per source
        DIMENSIONS = 128 # Embedding dimension
        DIRECTED = False # Graph directed/undirected
        WORKERS = 8 # Num. parallel workers
        ITER = 1 # SGD epochs
        # Preprocessing, generate walks
        g_n2v = node2vec_lp.Graph(g_train, DIRECTED, P, Q) # create node2vec graph instance
        g_n2v.preprocess_transition_probs()
        walks = g_n2v.simulate_walks(NUM_WALKS, WALK_LENGTH)
        walks_str = []
        for walk in walks:
            t = [str(i) for i in walk]
            walks_str.append(t)
        walks = walks_str
        # walks = [list(map(str, walk) for walk in walks)]
        # # # Train skip-gram model
        model = word2vec.Word2Vec(walks, vector_size=DIMENSIONS, window=WINDOW_SIZE, min_count=0, sg=1, workers=WORKERS, epochs=ITER)
        # # Store embeddings mapping
        emb_mappings = model.wv
        # Create node embeddings matrix (rows = nodes, columns = embedding features)
        emb_list = []
        for node_index in range(0, adj_sparse.shape[0]):
            node_str = str(node_index)
            node_emb = emb_mappings[node_str]
            emb_list.append(node_emb)
        emb_matrix = np.vstack(emb_list)
        # Train-set edge embeddings
        pos_train_edge_embs = get_edge_embeddings(emb_matrix,train_edges)
        neg_train_edge_embs = get_edge_embeddings(emb_matrix,train_edges_false)
        train_edge_embs = np.concatenate([pos_train_edge_embs, neg_train_edge_embs])
        # Create train-set edge labels: 1 = real edge, 0 = false edge
        train_edge_labels = np.concatenate([np.ones(len(train_edges)), np.zeros(len(train_edges_false))])
        
        # Test-set edge embeddings, labels
        pos_test_edge_embs = get_edge_embeddings(emb_matrix,test_edges)
        neg_test_edge_embs = get_edge_embeddings(emb_matrix,test_edges_false)
        test_edge_embs = np.concatenate([pos_test_edge_embs, neg_test_edge_embs])
        # Create val-set edge labels: 1 = real edge, 0 = false edge
        test_edge_labels = np.concatenate([np.ones(len(test_edges)), np.zeros(len(test_edges_false))])

        # edge_classifier = LogisticRegression(random_state=0)
        # edge_classifier = RandomForestClassifier(random_state=0)
        # edge_classifier = SGDClassifier(loss='log_loss',random_state=0,penalty='l1')
        # edge_classifier = SVC(random_state=0,probability=True)
        edge_classifier = GradientBoostingClassifier(random_state=0)
        # edge_classifier = MLPClassifier(random_state=0)
        edge_classifier.fit(train_edge_embs, train_edge_labels)
        # Predicted edge scores: probability of being of class "1" (real edge)
        nv_test_preds = edge_classifier.predict_proba(test_edge_embs)[:, 1]
        nv_test_roc = roc_auc_score(test_edge_labels, nv_test_preds)
        nv_test_fpr, nv_test_tpr, _ = roc_curve(test_edge_labels, nv_test_preds)
        nv_test_ap = average_precision_score(test_edge_labels, nv_test_preds)
        nv_precision, nv_recall, _ = precision_recall_curve(test_edge_labels, nv_test_preds)
        print ('node2vec Test ROC score: ', str(nv_test_roc))
        print ('node2vec Test AP score: ', str(nv_test_ap))
        nv_result = [nv_test_roc,nv_precision,nv_test_fpr, nv_test_tpr,nv_test_ap,nv_precision, nv_recall]
        temp = [nv_result]
        spcs_temp[seed_num] = temp
    result[spcs] = spcs_temp
pickle.dump(result,open('./nv-graph_model-gbc.pkl','wb'))
# Out:
# Homo sapiens 12345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# node2vec Test ROC score:  0.8865405107697465
# node2vec Test AP score:  0.8817283348096382
# Homo sapiens 22345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# node2vec Test ROC score:  0.8809341363249961
# node2vec Test AP score:  0.878249916694859
# Homo sapiens 32345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# node2vec Test ROC score:  0.8886357921959745
# node2vec Test AP score:  0.8800829585493835
# Homo sapiens 42345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# node2vec Test ROC score:  0.8697333604722166
# node2vec Test AP score:  0.8738965284514025
# Homo sapiens 52345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# ...

# %%
species = ['Homo sapiens','Mus musculus','Rattus norvegicus','Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana','Saccharomyces cerevisiae','Drosophila melanogaster','Caenorhabditis elegans']
seed_number = [12345, 22345, 32345, 42345, 52345]
index = 0
error_message = []
result = {}
for spcs in species:
    spcs_temp = {}
    for seed_num in seed_number:
        mpi_file_name = './features/mpi_network/'+'mpi_'+str(spcs).replace(' ','_')+'.pkl'
        df_file_name = './features/mpi_features/'+'feature_df_'+str(spcs).replace(' ','_')+'.pkl'
        g = pickle.load(open(mpi_file_name, "rb" ))
        node_feats = pickle.load(open(df_file_name, "rb" ))
        adj = nx.adjacency_matrix(g,nodelist=node_feats['node'].tolist())
        adj_train, train_edges, train_edges_false, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges_seed(adj, test_frac=.1, val_frac=.1,seed=seed_num)
        adj_sparse = nx.to_scipy_sparse_matrix(g)
        g_train = nx.from_scipy_sparse_matrix(adj_train) # new graph object with only non-hidden edges
        print(spcs,seed_num) 
        # node2vec settings
        # NOTE: When p = q = 1, this is equivalent to DeepWalk
        P = 1 # Return hyperparameter
        Q = 1 # In-out hyperparameter
        WINDOW_SIZE = 10 # Context size for optimization
        NUM_WALKS = 10 # Number of walks per source
        WALK_LENGTH = 80 # Length of walk per source
        DIMENSIONS = 128 # Embedding dimension
        DIRECTED = False # Graph directed/undirected
        WORKERS = 8 # Num. parallel workers
        ITER = 1 # SGD epochs
        # Preprocessing, generate walks
        g_n2v = node2vec_lp.Graph(g_train, DIRECTED, P, Q) # create node2vec graph instance
        g_n2v.preprocess_transition_probs()
        walks = g_n2v.simulate_walks(NUM_WALKS, WALK_LENGTH)
        walks_str = []
        for walk in walks:
            t = [str(i) for i in walk]
            walks_str.append(t)
        walks = walks_str
        # walks = [list(map(str, walk) for walk in walks)]
        # # # Train skip-gram model
        model = word2vec.Word2Vec(walks, vector_size=DIMENSIONS, window=WINDOW_SIZE, min_count=0, sg=1, workers=WORKERS, epochs=ITER)
        # # Store embeddings mapping
        emb_mappings = model.wv
        # Create node embeddings matrix (rows = nodes, columns = embedding features)
        emb_list = []
        for node_index in range(0, adj_sparse.shape[0]):
            node_str = str(node_index)
            node_emb = emb_mappings[node_str]
            emb_list.append(node_emb)
        emb_matrix = np.vstack(emb_list)
        # Train-set edge embeddings
        pos_train_edge_embs = get_edge_embeddings(emb_matrix,train_edges)
        neg_train_edge_embs = get_edge_embeddings(emb_matrix,train_edges_false)
        train_edge_embs = np.concatenate([pos_train_edge_embs, neg_train_edge_embs])
        # Create train-set edge labels: 1 = real edge, 0 = false edge
        train_edge_labels = np.concatenate([np.ones(len(train_edges)), np.zeros(len(train_edges_false))])
        
        # Test-set edge embeddings, labels
        pos_test_edge_embs = get_edge_embeddings(emb_matrix,test_edges)
        neg_test_edge_embs = get_edge_embeddings(emb_matrix,test_edges_false)
        test_edge_embs = np.concatenate([pos_test_edge_embs, neg_test_edge_embs])
        # Create val-set edge labels: 1 = real edge, 0 = false edge
        test_edge_labels = np.concatenate([np.ones(len(test_edges)), np.zeros(len(test_edges_false))])

        # edge_classifier = LogisticRegression(random_state=0)
        # edge_classifier = RandomForestClassifier(random_state=0)
        # edge_classifier = SGDClassifier(loss='log_loss',random_state=0,penalty='l1')
        # edge_classifier = SVC(random_state=0,probability=True)
        # edge_classifier = GradientBoostingClassifier(random_state=0)
        edge_classifier = MLPClassifier(random_state=0)
        edge_classifier.fit(train_edge_embs, train_edge_labels)
        # Predicted edge scores: probability of being of class "1" (real edge)
        nv_test_preds = edge_classifier.predict_proba(test_edge_embs)[:, 1]
        nv_test_roc = roc_auc_score(test_edge_labels, nv_test_preds)
        nv_test_fpr, nv_test_tpr, _ = roc_curve(test_edge_labels, nv_test_preds)
        nv_test_ap = average_precision_score(test_edge_labels, nv_test_preds)
        nv_precision, nv_recall, _ = precision_recall_curve(test_edge_labels, nv_test_preds)
        print ('node2vec Test ROC score: ', str(nv_test_roc))
        print ('node2vec Test AP score: ', str(nv_test_ap))
        nv_result = [nv_test_roc,nv_precision,nv_test_fpr, nv_test_tpr,nv_test_ap,nv_precision, nv_recall]
        temp = [nv_result]
        spcs_temp[seed_num] = temp
    result[spcs] = spcs_temp
pickle.dump(result,open('./nv-graph_model-mlp.pkl','wb'))
# Out:
# Homo sapiens 12345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# /Users/chengwang/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# node2vec Test ROC score:  0.8941643419020366
# node2vec Test AP score:  0.8791078306781206
# Homo sapiens 22345
# Walk iteration:
# 1 / 10
# 2 / 10
# 3 / 10
# 4 / 10
# 5 / 10
# 6 / 10
# 7 / 10
# 8 / 10
# 9 / 10
# 10 / 10
# /Users/chengwang/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# node2vec Test ROC score:  0.8909645478382683
# node2vec Test AP score:  0.8928292868697743
# Homo sapiens 32345
# Walk iteration:
# 1 / 10
# ...

# %%
# Train logistic regression classifier on train-set edge embeddings
from sklearn.linear_model import LogisticRegression,Perceptron,SGDClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

# %%
Adamic_Ada_mpi(adj_sparse, g_train, test_edges, test_edges_false)
# Out:
# Adamic-Adar Test ROC score:  0.5285730928428497
# Adamic-Adar Test AP score:  0.5379927156949813
# [0.5285730928428497,
#  0.5379927156949813,
#  array([0.        , 0.0026178 , 0.0026178 , 0.0052356 , 0.0052356 ,
#         0.0078534 , 0.0078534 , 0.01308901, 0.01308901, 0.01832461,
#         0.01832461, 0.02094241, 0.02094241, 0.02356021, 0.02356021,
#         0.02356021, 0.02879581, 0.02879581, 0.02879581, 0.02879581,
#         0.02879581, 0.02879581, 0.03664921, 0.03664921, 0.03926702,
#         0.03926702, 0.04450262, 0.04450262, 0.04973822, 0.04973822,
#         0.05759162, 0.05759162, 0.06282723, 0.06806283, 0.07853403,
#         0.07853403, 0.08115183, 0.08115183, 0.08638743, 0.08638743,
#         0.09424084, 0.09424084, 0.09947644, 0.09947644, 0.10209424,
#         0.10209424, 0.10732984, 0.10732984, 0.10994764, 0.11518325,
#         0.11518325, 0.12041885, 0.12041885, 0.12303665, 0.12303665,
#         0.13089005, 0.13089005, 0.13350785, 0.13350785, 0.13874346,
# ...

# %%
species = ['Mus musculus','Rattus norvegicus','Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana','Saccharomyces cerevisiae','Drosophila melanogaster','Caenorhabditis elegans']
# species = ['Homo sapiens']

species = ['Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana']
seed_number = [12345, 22345, 32345, 42345, 52345]
index = 0
result = {}
for spcs in species[:1]:
    spcs_temp = {}
    for seed_num in seed_number:
        print(spcs,seed_num)
        # row = [[]]*len(list(result_charc))
        mpi_file_name = './features/mpi_network/'+'mpi_'+str(spcs).replace(' ','_')+'.pkl'
        df_file_name = './features/mpi_features/'+'feature_df_'+str(spcs).replace(' ','_')+'.pkl'
        g = pickle.load(open(mpi_file_name, "rb" ))
        node_feats = pickle.load(open(df_file_name, "rb" ))
        print(list(node_feats))
# Out:
# Escherichia coli 12345
# ['node', 'dbid', 'class', 'length', 'features', 'pca_1024', 'pca_512', 'pca_256']
# Escherichia coli 22345
# ['node', 'dbid', 'class', 'length', 'features', 'pca_1024', 'pca_512', 'pca_256']
# Escherichia coli 32345
# ['node', 'dbid', 'class', 'length', 'features', 'pca_1024', 'pca_512', 'pca_256']
# Escherichia coli 42345
# ['node', 'dbid', 'class', 'length', 'features', 'pca_1024', 'pca_512', 'pca_256']
# Escherichia coli 52345
# ['node', 'dbid', 'class', 'length', 'features', 'pca_1024', 'pca_512', 'pca_256']

# %%
species = ['Homo sapiens','Mus musculus','Rattus norvegicus','Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana','Saccharomyces cerevisiae','Drosophila melanogaster','Caenorhabditis elegans']
# species = ['Homo sapiens']

# species = ['Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana']
seed_number = [12345, 22345, 32345, 42345, 52345]
index = 0
result = {}
for spcs in species:
    spcs_temp = {}
    for seed_num in seed_number:
        print(spcs,seed_num)
        # row = [[]]*len(list(result_charc))
        mpi_file_name = './features/mpi_network/'+'pca_mpi_'+str(spcs).replace(' ','_')+'.pkl'
        df_file_name = './features/mpi_features/'+'pca_feature_df_'+str(spcs).replace(' ','_')+'.pkl'
        g = pickle.load(open(mpi_file_name, "rb" ))
        node_feats = pickle.load(open(df_file_name, "rb" ))
        features = np.stack(node_feats['pca_16'].values, axis=0)
        adj = nx.adjacency_matrix(g,nodelist=node_feats['node'].tolist())
        # features = np.random.rand(adj.shape[0],1024)
        adj_train, train_edges, train_edges_false, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges_seed(adj, test_frac=.1, val_frac=.1,seed=seed_num)
        
        x = sp.lil_matrix(features)
        features_tuple = sparse_to_tuple(x)
        features_shape = features_tuple[2]
        # Get graph attributes (to feed into model)
        num_nodes = adj.shape[0] # number of nodes in adjacency matrix
        num_features = features_shape[1] # number of features (columsn of features matrix)
        features_nonzero = features_tuple[1].shape[0] # number of non-zero entries in features matrix (or length of values list)
        # Store original adjacency matrix (without diagonal entries) for later
        adj_orig = adj
        adj_orig = adj_orig - sp.dia_matrix((adj_orig.diagonal()[np.newaxis, :], [0]), shape=adj_orig.shape)
        adj_orig.eliminate_zeros()
        # Normalize adjacency matrix
        adj_norm = preprocess_graph(adj_train)
        # Add in diagonals
        adj_label = adj_train + sp.eye(adj_train.shape[0])
        adj_label = sparse_to_tuple(adj_label)
        cost_val = []
        acc_val = []
        val_roc_score = []
        train_loss_log = []
        val_loss_log = []
        # Define hyperparameters
        LEARNING_RATE = 0.005
        EPOCHS = 200
        HIDDEN1_DIM = 32
        HIDDEN2_DIM = 16
        DROPOUT = 0.1
        # Define placeholders
        placeholders = {
            'features': tf.sparse_placeholder(tf.float32),
            'adj': tf.sparse_placeholder(tf.float32),
            'adj_orig': tf.sparse_placeholder(tf.float32),
            'dropout': tf.placeholder_with_default(0., shape=())
        }

        # How much to weigh positive examples (true edges) in cost print_function
        # Want to weigh less-frequent classes higher, so as to prevent model output bias
        # pos_weight = (num. negative samples / (num. positive samples)
        pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()

        # normalize (scale) average weighted cost
        norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0] - adj.sum()) * 2)

        # Create VAE model
        model = GCNModelVAE(placeholders, num_features, num_nodes, features_nonzero, HIDDEN1_DIM, HIDDEN2_DIM)

        opt = OptimizerVAE(preds=model.reconstructions,
                                labels=tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                            validate_indices=False), [-1]),
                                model=model, num_nodes=num_nodes,
                                pos_weight=pos_weight,
                                norm=norm,
                                learning_rate=LEARNING_RATE)

        # Initialize session
        sess = tf.Session()
        sess.run(tf.global_variables_initializer())

        # Train model
        for epoch in range(EPOCHS):
            t = time.time()
            # Construct feed dictionary
            feed_dict = construct_feed_dict(adj_norm, adj_label, features_tuple, placeholders)
            feed_dict.update({placeholders['dropout']: DROPOUT})
            # Run single weight update
            outs = sess.run([opt.opt_op, opt.cost, opt.accuracy], feed_dict=feed_dict)

            # Compute average loss
            avg_cost = outs[1]
            avg_accuracy = outs[2]
            roc_curr, ap_curr, fpr, tpr, pr_score, precision, recall = get_roc_score_vgae(train_edges, train_edges_false, pos_weight, norm)
            # train_loss_log.append(train_loss_epoch)

            # # Evaluate predictions
            roc_curr, ap_curr, fpr, tpr, pr_score, precision, recall = get_roc_score_vgae(val_edges, val_edges_false, pos_weight, norm)
            val_roc_score.append(roc_curr)
            # val_loss_log.append(val_loss_epoch)
            
            if (epoch+1)%50 == 0:
            # Print results for this epoch
                print("Epoch:", '%04d' % (epoch + 1), "train_loss=", "{:.5f}".format(avg_cost),
                    "train_acc=", "{:.5f}".format(avg_accuracy), "val_roc=", "{:.5f}".format(val_roc_score[-1]),
                    "val_ap=", "{:.5f}".format(ap_curr),
                    "time=", "{:.5f}".format(time.time() - t))

        print("Optimization Finished!")
        # Print final results
        feature_roc_score, feature_ap_score, feature_fpr, feature_tpr, feature_pr_score, feature_prcs, feature_rcal = get_roc_score_vgae(test_edges, test_edges_false, pos_weight, norm)
        temp = [feature_roc_score, feature_ap_score, feature_fpr, feature_tpr, feature_pr_score, feature_prcs, feature_rcal]
        print('Test ROC score: ' + str(feature_roc_score))
        print('Test AP score: ' + str(feature_ap_score))
        spcs_temp[seed_num] = temp
    result[spcs] = spcs_temp
pickle.dump(result,open('./graph_model_vgae_no_feats-all.pkl','wb'))
# Out:
# Homo sapiens 12345
# Creating GAE optimizer...
# Labels shape:  (?,)
# Preds shape:  (?,)
# CE+KL loss shape:  ()
# Epoch: 0050 train_loss= 0.62202 train_acc= 0.46602 val_roc= 0.75525 val_ap= 0.76978 time= 0.47040
# Epoch: 0100 train_loss= 0.55991 train_acc= 0.48993 val_roc= 0.79782 val_ap= 0.81092 time= 0.46847
# Epoch: 0150 train_loss= 0.53775 train_acc= 0.49851 val_roc= 0.83055 val_ap= 0.84839 time= 0.46126
# Epoch: 0200 train_loss= 0.52817 train_acc= 0.50165 val_roc= 0.83101 val_ap= 0.84640 time= 0.45391
# Optimization Finished!
# Test ROC score: 0.8396361394140395
# Test AP score: 0.8480554591716682
# Homo sapiens 22345
# Creating GAE optimizer...
# Labels shape:  (?,)
# Preds shape:  (?,)
# CE+KL loss shape:  ()
# Epoch: 0050 train_loss= 0.66680 train_acc= 0.47825 val_roc= 0.73755 val_ap= 0.75315 time= 0.45762
# Epoch: 0100 train_loss= 0.58169 train_acc= 0.49131 val_roc= 0.79544 val_ap= 0.80892 time= 0.46279
# ...

# %%
species = ['Homo sapiens','Mus musculus','Rattus norvegicus','Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana','Saccharomyces cerevisiae','Drosophila melanogaster','Caenorhabditis elegans']
# species = ['Homo sapiens']

# species = ['Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana']
seed_number = [12345, 22345, 32345, 42345, 52345]
index = 0
result = {}
for spcs in species[-5:-4]:
    spcs_temp = {}
    for seed_num in seed_number:
        print(spcs,seed_num)
        # row = [[]]*len(list(result_charc))
        mpi_file_name = './features/mpi_network/'+'mpi_'+str(spcs).replace(' ','_')+'.pkl'
        df_file_name = './features/mpi_features/'+'feature_df_'+str(spcs).replace(' ','_')+'.pkl'
        g = pickle.load(open(mpi_file_name, "rb" ))
        node_feats = pickle.load(open(df_file_name, "rb" ))
        # features = np.stack(node_feats['pca_512'].values, axis=0)
        adj = nx.adjacency_matrix(g,nodelist=node_feats['node'].tolist())
        features = np.random.rand(adj.shape[0],1024)
        adj_train, train_edges, train_edges_false, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges_seed(adj, test_frac=.1, val_frac=.1,seed=seed_num)
        
        x = sp.lil_matrix(features)
        features_tuple = sparse_to_tuple(x)
        features_shape = features_tuple[2]
        # Get graph attributes (to feed into model)
        num_nodes = adj.shape[0] # number of nodes in adjacency matrix
        num_features = features_shape[1] # number of features (columsn of features matrix)
        features_nonzero = features_tuple[1].shape[0] # number of non-zero entries in features matrix (or length of values list)
        # Store original adjacency matrix (without diagonal entries) for later
        adj_orig = adj
        adj_orig = adj_orig - sp.dia_matrix((adj_orig.diagonal()[np.newaxis, :], [0]), shape=adj_orig.shape)
        adj_orig.eliminate_zeros()
        # Normalize adjacency matrix
        adj_norm = preprocess_graph(adj_train)
        # Add in diagonals
        adj_label = adj_train + sp.eye(adj_train.shape[0])
        adj_label = sparse_to_tuple(adj_label)
        cost_val = []
        acc_val = []
        val_roc_score = []
        train_loss_log = []
        val_loss_log = []
        # Define hyperparameters
        LEARNING_RATE = 0.005
        EPOCHS = 500
        HIDDEN1_DIM = 32
        HIDDEN2_DIM = 16
        DROPOUT = 0.1
        # Define placeholders
        placeholders = {
            'features': tf.sparse_placeholder(tf.float32),
            'adj': tf.sparse_placeholder(tf.float32),
            'adj_orig': tf.sparse_placeholder(tf.float32),
            'dropout': tf.placeholder_with_default(0., shape=())
        }

        # How much to weigh positive examples (true edges) in cost print_function
        # Want to weigh less-frequent classes higher, so as to prevent model output bias
        # pos_weight = (num. negative samples / (num. positive samples)
        pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()

        # normalize (scale) average weighted cost
        norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0] - adj.sum()) * 2)

        # Create VAE model
        model = GCNModelVAE(placeholders, num_features, num_nodes, features_nonzero, HIDDEN1_DIM, HIDDEN2_DIM)

        opt = OptimizerVAE(preds=model.reconstructions,
                                labels=tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                            validate_indices=False), [-1]),
                                model=model, num_nodes=num_nodes,
                                pos_weight=pos_weight,
                                norm=norm,
                                learning_rate=LEARNING_RATE)

        # Initialize session
        sess = tf.Session()
        sess.run(tf.global_variables_initializer())

        # Train model
        for epoch in range(EPOCHS):
            t = time.time()
            # Construct feed dictionary
            feed_dict = construct_feed_dict(adj_norm, adj_label, features_tuple, placeholders)
            feed_dict.update({placeholders['dropout']: DROPOUT})
            # Run single weight update
            outs = sess.run([opt.opt_op, opt.cost, opt.accuracy], feed_dict=feed_dict)

            # Compute average loss
            avg_cost = outs[1]
            avg_accuracy = outs[2]
            roc_curr, ap_curr, fpr, tpr, pr_score, precision, recall = get_roc_score_vgae(train_edges, train_edges_false, pos_weight, norm)
            # train_loss_log.append(train_loss_epoch)

            # # Evaluate predictions
            roc_curr, ap_curr, fpr, tpr, pr_score, precision, recall = get_roc_score_vgae(val_edges, val_edges_false, pos_weight, norm)
            val_roc_score.append(roc_curr)
            # val_loss_log.append(val_loss_epoch)
            
            if (epoch+1)%50 == 0:
            # Print results for this epoch
                print("Epoch:", '%04d' % (epoch + 1), "train_loss=", "{:.5f}".format(avg_cost),
                    "train_acc=", "{:.5f}".format(avg_accuracy), "val_roc=", "{:.5f}".format(val_roc_score[-1]),
                    "val_ap=", "{:.5f}".format(ap_curr),
                    "time=", "{:.5f}".format(time.time() - t))

        print("Optimization Finished!")
        # Print final results
        feature_roc_score, feature_ap_score, feature_fpr, feature_tpr, feature_pr_score, feature_prcs, feature_rcal = get_roc_score_vgae(test_edges, test_edges_false, pos_weight, norm)
        temp = [feature_roc_score, feature_ap_score, feature_fpr, feature_tpr, feature_pr_score, feature_prcs, feature_rcal]
        print('Test ROC score: ' + str(feature_roc_score))
        print('Test AP score: ' + str(feature_ap_score))
        spcs_temp[seed_num] = temp
    result[spcs] = spcs_temp
pickle.dump(result,open('./graph_model_vgae_no_feats-Pseudomonas.pkl','wb'))
# Out:
# Pseudomonas aeruginosa 12345
# Creating GAE optimizer...
# Labels shape:  (?,)
# Preds shape:  (?,)
# CE+KL loss shape:  ()
# Epoch: 0050 train_loss= 5633.45215 train_acc= 0.00529 val_roc= 0.50000 val_ap= 0.50000 time= 0.34864
# Epoch: 0100 train_loss= 2288.87573 train_acc= 0.00896 val_roc= 0.50000 val_ap= 0.50000 time= 0.44229
# Epoch: 0150 train_loss= 4345.89014 train_acc= 0.01094 val_roc= 0.50000 val_ap= 0.50000 time= 0.41487
# Epoch: 0200 train_loss= 1479.65747 train_acc= 0.01356 val_roc= 0.50000 val_ap= 0.50000 time= 0.32665
# Epoch: 0250 train_loss= 1864.46143 train_acc= 0.01669 val_roc= 0.50000 val_ap= 0.50000 time= 0.31562
# Epoch: 0300 train_loss= 456.59720 train_acc= 0.01641 val_roc= 0.50000 val_ap= 0.50000 time= 0.42770
# Epoch: 0350 train_loss= 2388.44580 train_acc= 0.00936 val_roc= 0.50000 val_ap= 0.50000 time= 0.32046
# Epoch: 0400 train_loss= 6014.52100 train_acc= 0.01207 val_roc= 0.50000 val_ap= 0.50000 time= 0.31359
# ...

# %%
species = ['Homo sapiens','Mus musculus','Rattus norvegicus','Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana','Saccharomyces cerevisiae','Drosophila melanogaster','Caenorhabditis elegans']
# species = ['Homo sapiens']

# species = ['Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana']
seed_number = [12345, 22345, 32345, 42345, 52345]
index = 0
result = {}
for spcs in species[:1]:
    spcs_temp = {}
    for seed_num in seed_number:
        print(spcs,seed_num)
        # row = [[]]*len(list(result_charc))
        mpi_file_name = './features/mpi_network/'+'mpi_'+str(spcs).replace(' ','_')+'.pkl'
        df_file_name = './features/mpi_features/'+'feature_df_'+str(spcs).replace(' ','_')+'.pkl'
        g = pickle.load(open(mpi_file_name, "rb" ))
        node_feats = pickle.load(open(df_file_name, "rb" ))
        features = np.stack(node_feats['pca_256'].values, axis=0)
        adj = nx.adjacency_matrix(g,nodelist=node_feats['node'].tolist())
        # features = np.random.rand(adj.shape[0],1024)
        adj_train, train_edges, train_edges_false, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges_seed(adj, test_frac=.1, val_frac=.1,seed=seed_num)
        
        x = sp.lil_matrix(features)
        features_tuple = sparse_to_tuple(x)
        features_shape = features_tuple[2]
        # Get graph attributes (to feed into model)
        num_nodes = adj.shape[0] # number of nodes in adjacency matrix
        num_features = features_shape[1] # number of features (columsn of features matrix)
        features_nonzero = features_tuple[1].shape[0] # number of non-zero entries in features matrix (or length of values list)
        # Store original adjacency matrix (without diagonal entries) for later
        adj_orig = adj
        adj_orig = adj_orig - sp.dia_matrix((adj_orig.diagonal()[np.newaxis, :], [0]), shape=adj_orig.shape)
        adj_orig.eliminate_zeros()
        # Normalize adjacency matrix
        adj_norm = preprocess_graph(adj_train)
        # Add in diagonals
        adj_label = adj_train + sp.eye(adj_train.shape[0])
        adj_label = sparse_to_tuple(adj_label)
        cost_val = []
        acc_val = []
        val_roc_score = []
        train_loss_log = []
        val_loss_log = []
        # Define hyperparameters
        LEARNING_RATE = 0.005
        EPOCHS = 500
        HIDDEN1_DIM = 32
        HIDDEN2_DIM = 16
        DROPOUT = 0.1
        # Define placeholders
        placeholders = {
            'features': tf.sparse_placeholder(tf.float32),
            'adj': tf.sparse_placeholder(tf.float32),
            'adj_orig': tf.sparse_placeholder(tf.float32),
            'dropout': tf.placeholder_with_default(0., shape=())
        }

        # How much to weigh positive examples (true edges) in cost print_function
        # Want to weigh less-frequent classes higher, so as to prevent model output bias
        # pos_weight = (num. negative samples / (num. positive samples)
        pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()

        # normalize (scale) average weighted cost
        norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0] - adj.sum()) * 2)

        # Create VAE model
        model = GCNModelVAE(placeholders, num_features, num_nodes, features_nonzero, HIDDEN1_DIM, HIDDEN2_DIM)

        opt = OptimizerVAE(preds=model.reconstructions,
                                labels=tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                            validate_indices=False), [-1]),
                                model=model, num_nodes=num_nodes,
                                pos_weight=pos_weight,
                                norm=norm,
                                learning_rate=LEARNING_RATE)

        # Initialize session
        sess = tf.Session()
        sess.run(tf.global_variables_initializer())

        # Train model
        for epoch in range(EPOCHS):
            t = time.time()
            # Construct feed dictionary
            feed_dict = construct_feed_dict(adj_norm, adj_label, features_tuple, placeholders)
            feed_dict.update({placeholders['dropout']: DROPOUT})
            # Run single weight update
            outs = sess.run([opt.opt_op, opt.cost, opt.accuracy], feed_dict=feed_dict)

            # Compute average loss
            avg_cost = outs[1]
            avg_accuracy = outs[2]
            roc_curr, ap_curr, fpr, tpr, pr_score, precision, recall = get_roc_score_vgae(train_edges, train_edges_false, pos_weight, norm)
            # train_loss_log.append(train_loss_epoch)

            # # Evaluate predictions
            roc_curr, ap_curr, fpr, tpr, pr_score, precision, recall = get_roc_score_vgae(val_edges, val_edges_false, pos_weight, norm)
            val_roc_score.append(roc_curr)
            # val_loss_log.append(val_loss_epoch)
            
            if (epoch+1)%50 == 0:
            # Print results for this epoch
                print("Epoch:", '%04d' % (epoch + 1), "train_loss=", "{:.5f}".format(avg_cost),
                    "train_acc=", "{:.5f}".format(avg_accuracy), "val_roc=", "{:.5f}".format(val_roc_score[-1]),
                    "val_ap=", "{:.5f}".format(ap_curr),
                    "time=", "{:.5f}".format(time.time() - t))

        print("Optimization Finished!")
        # Print final results
        feature_roc_score, feature_ap_score, feature_fpr, feature_tpr, feature_pr_score, feature_prcs, feature_rcal = get_roc_score_vgae(test_edges, test_edges_false, pos_weight, norm)
        temp = [feature_roc_score, feature_ap_score, feature_fpr, feature_tpr, feature_pr_score, feature_prcs, feature_rcal]
        print('Test ROC score: ' + str(feature_roc_score))
        print('Test AP score: ' + str(feature_ap_score))
        spcs_temp[seed_num] = temp
    result[spcs] = spcs_temp
pickle.dump(result,open('./graph_model_vgae_pca_256.pkl','wb'))
# Out:
# Homo sapiens 12345
# Creating GAE optimizer...
# Labels shape:  (?,)
# Preds shape:  (?,)
# CE+KL loss shape:  ()
# Epoch: 0050 train_loss= 0.54820 train_acc= 0.49602 val_roc= 0.84476 val_ap= 0.84707 time= 0.50443
# Epoch: 0100 train_loss= 0.50124 train_acc= 0.50376 val_roc= 0.88232 val_ap= 0.88647 time= 0.50930
# Epoch: 0150 train_loss= 0.47793 train_acc= 0.51085 val_roc= 0.90514 val_ap= 0.91353 time= 0.48794
# Epoch: 0200 train_loss= 0.46663 train_acc= 0.51224 val_roc= 0.91155 val_ap= 0.92241 time= 0.46740
# Epoch: 0250 train_loss= 0.46195 train_acc= 0.51945 val_roc= 0.91932 val_ap= 0.93130 time= 0.48143
# Epoch: 0300 train_loss= 0.45882 train_acc= 0.51797 val_roc= 0.91907 val_ap= 0.93199 time= 0.50109
# Epoch: 0350 train_loss= 0.45448 train_acc= 0.52249 val_roc= 0.91699 val_ap= 0.93045 time= 0.47114
# Epoch: 0400 train_loss= 0.45096 train_acc= 0.52545 val_roc= 0.92233 val_ap= 0.93584 time= 0.47353
# ...

# %%
species = ['Homo sapiens','Mus musculus','Rattus norvegicus','Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana','Saccharomyces cerevisiae','Drosophila melanogaster','Caenorhabditis elegans']
# species = ['Homo sapiens']

# species = ['Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana']
seed_number = [12345, 22345, 32345, 42345, 52345]
index = 0
result = {}
for spcs in species[:1]:
    spcs_temp = {}
    for seed_num in seed_number[:1]:
        print(spcs,seed_num)
        # row = [[]]*len(list(result_charc))
        mpi_file_name = './features/mpi_network/'+'mpi_'+str(spcs).replace(' ','_')+'.pkl'
        df_file_name = './features/mpi_features/'+'feature_df_'+str(spcs).replace(' ','_')+'.pkl'
        g = pickle.load(open(mpi_file_name, "rb" ))
        node_feats = pickle.load(open(df_file_name, "rb" ))
        features = np.stack(node_feats['features'].values, axis=0)
        adj = nx.adjacency_matrix(g,nodelist=node_feats['node'].tolist())
        # features = np.random.rand(adj.shape[0],1024)
        adj_train, train_edges, train_edges_false, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges_seed(adj, test_frac=.1, val_frac=.1,seed=seed_num)
        
        # edge_false_all = create_all_false_edges(adj)
        # train_edges_false = set()
        # for i in edge_false_all:
        #     train_edges_false.add(i)
        # train_edges_false = np.array([list(edge_tuple) for edge_tuple in train_edges_false])
        
        x = sp.lil_matrix(features)
        features_tuple = sparse_to_tuple(x)
        features_shape = features_tuple[2]
        # Get graph attributes (to feed into model)
        num_nodes = adj.shape[0] # number of nodes in adjacency matrix
        num_features = features_shape[1] # number of features (columsn of features matrix)
        features_nonzero = features_tuple[1].shape[0] # number of non-zero entries in features matrix (or length of values list)
        # Store original adjacency matrix (without diagonal entries) for later
        adj_orig = adj
        adj_orig = adj_orig - sp.dia_matrix((adj_orig.diagonal()[np.newaxis, :], [0]), shape=adj_orig.shape)
        adj_orig.eliminate_zeros()
        # Normalize adjacency matrix
        adj_norm = preprocess_graph(adj_train)
        # Add in diagonals
        adj_label = adj_train + sp.eye(adj_train.shape[0])
        adj_label = sparse_to_tuple(adj_label)
        cost_val = []
        acc_val = []
        val_roc_score = []
        train_loss_log = []
        val_loss_log = []
        # Define hyperparameters
        LEARNING_RATE = 0.005
        EPOCHS = 500
        HIDDEN1_DIM = 32
        HIDDEN2_DIM = 16
        DROPOUT = 0.1
        # Define placeholders
        placeholders = {
            'features': tf.sparse_placeholder(tf.float32),
            'adj': tf.sparse_placeholder(tf.float32),
            'adj_orig': tf.sparse_placeholder(tf.float32),
            'dropout': tf.placeholder_with_default(0., shape=())
        }

        # How much to weigh positive examples (true edges) in cost print_function
        # Want to weigh less-frequent classes higher, so as to prevent model output bias
        # pos_weight = (num. negative samples / (num. positive samples)
        pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()

        # normalize (scale) average weighted cost
        norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0] - adj.sum()) * 2)

        # Create VAE model
        # model = GCNModelAE(placeholders, num_features, num_nodes, features_nonzero, HIDDEN1_DIM, HIDDEN2_DIM)
        model = GCNModelAE(placeholders, num_features, num_nodes, features_nonzero, HIDDEN1_DIM, HIDDEN2_DIM)

        # opt = OptimizerAE(preds=model.reconstructions,
        #                         labels=tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
        #                                                                     validate_indices=False), [-1]),
        #                         model=model, num_nodes=num_nodes,
        #                         pos_weight=pos_weight,
        #                         norm=norm,
        #                         learning_rate=LEARNING_RATE)

        opt = OptimizerAE(preds=model.reconstructions,
                                labels=tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                            validate_indices=False), [-1]),
                                model=model,
                                pos_weight=pos_weight,
                                norm=norm,
                                learning_rate=LEARNING_RATE)

        # Initialize session
        sess = tf.Session()
        sess.run(tf.global_variables_initializer())

        # Train model
        for epoch in range(EPOCHS):
            t = time.time()
            # Construct feed dictionary
            feed_dict = construct_feed_dict(adj_norm, adj_label, features_tuple, placeholders)
            feed_dict.update({placeholders['dropout']: DROPOUT})
            # Run single weight update
            outs = sess.run([opt.opt_op, opt.cost, opt.accuracy], feed_dict=feed_dict)

            # Compute average loss
            avg_cost = outs[1]
            avg_accuracy = outs[2]
            roc_curr, ap_curr, fpr, tpr, pr_score, precision, recall = get_roc_score_vgae(train_edges, train_edges_false, pos_weight, norm)
            # train_loss_log.append(train_loss_epoch)

            # # Evaluate predictions
            roc_curr, ap_curr, fpr, tpr, pr_score, precision, recall = get_roc_score_vgae(val_edges, val_edges_false, pos_weight, norm)
            val_roc_score.append(roc_curr)
            # val_loss_log.append(val_loss_epoch)
            
            if (epoch+1)%50 == 0:
            # Print results for this epoch
                print("Epoch:", '%04d' % (epoch + 1), "train_loss=", "{:.5f}".format(avg_cost),
                    "train_acc=", "{:.5f}".format(avg_accuracy), "val_roc=", "{:.5f}".format(val_roc_score[-1]),
                    "val_ap=", "{:.5f}".format(ap_curr),
                    "time=", "{:.5f}".format(time.time() - t))

        print("Optimization Finished!")
        # Print final results
        feature_roc_score, feature_ap_score, feature_fpr, feature_tpr, feature_pr_score, feature_prcs, feature_rcal = get_roc_score_vgae(test_edges, test_edges_false, pos_weight, norm)
        temp = [feature_roc_score, feature_ap_score, feature_fpr, feature_tpr, feature_pr_score, feature_prcs, feature_rcal]
        print('Test ROC score: ' + str(feature_roc_score))
        print('Test AP score: ' + str(feature_ap_score))
        spcs_temp[seed_num] = temp
    result[spcs] = spcs_temp
# pickle.dump(result,open('./graph_model_vgae_pca_256.pkl','wb'))
# Out:
# Homo sapiens 12345
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-363-d09afbfebaa5> in <module>
#      81         #                         learning_rate=LEARNING_RATE)
#      82
# ---> 83         opt = OptimizerAE(preds=model.reconstructions,
#      84                                 labels=tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
#      85                                                                             validate_indices=False), [-1]),
#
# TypeError: __init__() got an unexpected keyword argument 'model'

# %%
def vgae_pred(test,emb=None):
    if emb is None:
        feed_dict.update({placeholders['dropout']: 0})
        emb = sess.run(model.z_mean, feed_dict=feed_dict)
    
    def sigmoid(x):
        return 1 / (1 + np.exp(-x))

    # Predict on test set of edges
    adj_rec = np.dot(emb, emb.T)
    preds_pos = []
    pos = []
    for e in test:
        preds_pos.append(sigmoid(adj_rec[e[0], e[1]])) # predicted score for given edge
        pos.append(adj_orig[e[0], e[1]]) # actual value (1)
    return np.array(preds_pos),np.array(pos)

# %%
def create_all_false_edges(adj):
    # Sample false edges from G-complement, instead of randomly generating edges
    # g_complement = nx.complement(g)
    adj_complement = 1 - adj.toarray() # flip 0's, 1's in adjacency matrix
    np.fill_diagonal(adj_complement, val=0) # set diagonals to 0
    adj_complement = np.triu(adj_complement)
    print(adj_complement.shape)
    # 2 numpy arrays indicating x, y coords in adj_complement
        # WARNING: This line can use up a lot of RAM depending on 'adj' size
    idx1, idx2 = np.where(adj_complement == 1) 
        
    edges_false = np.stack((idx1, idx2), axis=-1) # stack arrays into coord pairs.
    edge_pairs_false = [(edge[0], edge[1]) for edge in edges_false]

    # Shuffle and iterate over false edges
    np.random.shuffle(edge_pairs_false)
    return edge_pairs_false

# %%
# Out:
# (2306, 2306)

# %%
edge_false_all = create_all_false_edges(adj)
train_edges_false = set()
for i in edge_false_all:
    train_edges_false.add(i)
train_edges_false = np.array([list(edge_tuple) for edge_tuple in train_edges_false])

# %%
print(nx.info(g))
# Out:
# Name:
# Type: Graph
# Number of nodes: 2306
# Number of edges: 5785
# Average degree:   5.0173

# %%
len(edge_false_all)
# Out:
# 2651880

# %%
5785/(2651880+5785)
# Out:
# 0.002176722799901417

# %%
len(test_edges)/len(edge_false_all)
# Out:
# 0.00021795858032791832

# %%
true_test_pred, test_pos = vgae_pred(train_edges)
false_test_pred, test_neg = vgae_pred(edge_false_all)

# %%
tt_feature_roc_score, tt_feature_ap_score, tt_feature_fpr, tt_feature_tpr, tt_feature_pr_score, tt_feature_prcs, tt_feature_rcal = get_roc_score_vgae(test_edges, edge_false_all, pos_weight, norm)

# %%
# Compute ROC curve and ROC area
plt.figure(figsize = (10,10))
lw = 2
plt.plot(tt_feature_fpr, tt_feature_tpr, color='#bf0001', label='VGAE + Structure: %.3f' % tt_feature_roc_score,lw = 2)
plt.plot([0, 1], [0, 1], color='black', lw=lw, linestyle='--')
# plt.xticks(np.arange(0,1,5),fontsize=15)
# plt.yticks(np.arange(0,1,5),fontsize=15)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate',fontsize = 20)
plt.ylabel('True Positive Rate',fontsize = 20)
plt.legend(loc="lower right")
plt.legend(fontsize=20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
filename = './train_output/roc_mpi_all_edges.pdf'
plt.savefig(filename)
plt.show()

# %%
578/2651880
# Out:
# 0.00021795858032791832

# %%
# Compute ROC curve and ROC area
plt.figure(figsize = (10,10))
lw = 2
plt.plot(tt_feature_rcal, tt_feature_prcs, color='#bf0001', label='VGAE + Structure: %.3f' % tt_feature_pr_score,lw = 2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('Recall',fontsize = 20)
plt.ylabel('Precision',fontsize = 20)
plt.legend(loc="lower right")
plt.legend(fontsize=20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
filename = './train_output/pr_mpi_all_edges.pdf'
plt.savefig(filename)
plt.show()

# %%
tt_feature_pr_score
# Out:
# 0.016002663729054564

# %%
cutoff = 0.6

# %%
test_TP = true_test_pred[np.where(true_test_pred>=cutoff)]
test_TN = false_test_pred[np.where(false_test_pred<cutoff)]
test_FN = true_test_pred[np.where(true_test_pred<cutoff)]
test_FP = false_test_pred[np.where(false_test_pred>=cutoff)]

# %%
N = len(test_TP)+len(test_FP)

# %%
test_TPR = len(test_TP)/(len(test_TP)+len(test_FN))
test_FPR = len(test_FP)/(len(test_FP)+len(test_TN))
print('TPR: %.3f' % test_TPR)
print('FPR: %.3f' % test_FPR)
# Out:
# TPR: 0.997
# FPR: 0.241

# %%
test_Precision = len(test_TP)/(len(test_TP)+len(test_FN))
test_Recall = len(test_TP)/(len(test_TP)+len(test_FP))
print('Precision: %.3f' % test_Precision)
print('Recall: %.3f' % test_Recall)
# Out:
# Precision: 0.997
# Recall: 0.007

# %%
sns.set_style('ticks')

# %%
plt.figure(figsize = (12,10))
data = np.array([[len(test_TP),len(test_FN)],[len(test_FP),len(test_TN)]])
df_cm = pd.DataFrame(data, columns=[['Positive','Negative']], index = [['Positive','Negative']])
# sns.set(font_scale=1.4)#for label size
sns.heatmap(df_cm, cmap="Blues", annot=True,annot_kws={"size": 20},fmt='g')# font size
plt.xlabel('Predicted',fontsize=20)
plt.ylabel('True',fontsize=20)
plt.savefig("./train_output/all_edge_confusion_matrix.pdf")
plt.show()

# %%
species = ['Homo sapiens','Mus musculus','Rattus norvegicus','Escherichia coli','Bos taurus','Pseudomonas aeruginosa','Arabidopsis thaliana','Saccharomyces cerevisiae','Drosophila melanogaster','Caenorhabditis elegans']
seed_number = [12345, 22345, 32345, 42345, 52345]
index = 0
result = {}

# %%
spcs_temp = {}
spcs = species[0]
seed_num = seed_number[0]
print(spcs,seed_num)
# row = [[]]*len(list(result_charc))
mpi_file_name = './features/mpi_network/'+'mpi_'+str(spcs).replace(' ','_')+'.pkl'
df_file_name = './features/mpi_features/'+'feature_df_'+str(spcs).replace(' ','_')+'.pkl'
g = pickle.load(open(mpi_file_name, "rb" ))
node_feats = pickle.load(open(df_file_name, "rb" ))
features = np.stack(node_feats['features'].values, axis=0)
adj = nx.adjacency_matrix(g,nodelist=node_feats['node'].tolist())
adj_train, train_edges, train_edges_false, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges_seed(adj, test_frac=.1, val_frac=.1,seed=seed_num)
# Out:
# Homo sapiens 12345

# %%
x = sp.lil_matrix(features)
features_tuple = sparse_to_tuple(x)
features_shape = features_tuple[2]
# Get graph attributes (to feed into model)
num_nodes = adj.shape[0] # number of nodes in adjacency matrix
num_features = features_shape[1] # number of features (columsn of features matrix)
features_nonzero = features_tuple[1].shape[0] # number of non-zero entries in features matrix (or length of values list)
# Store original adjacency matrix (without diagonal entries) for later
adj_orig = adj
adj_orig = adj_orig - sp.dia_matrix((adj_orig.diagonal()[np.newaxis, :], [0]), shape=adj_orig.shape)
adj_orig.eliminate_zeros()
# Normalize adjacency matrix
adj_norm = preprocess_graph(adj_train)
# Add in diagonals
adj_label = adj_train + sp.eye(adj_train.shape[0])
adj_label = sparse_to_tuple(adj_label)
cost_val = []
acc_val = []
val_roc_score = []
train_loss_log = []
val_loss_log = []
# Define hyperparameters
LEARNING_RATE = 0.005
EPOCHS = 600
HIDDEN1_DIM = 32
HIDDEN2_DIM = 16
DROPOUT = 0.1
# Define placeholders
placeholders = {
    'features': tf.sparse_placeholder(tf.float32),
    'adj': tf.sparse_placeholder(tf.float32),
    'adj_orig': tf.sparse_placeholder(tf.float32),
    'dropout': tf.placeholder_with_default(0., shape=())
}

# How much to weigh positive examples (true edges) in cost print_function
# Want to weigh less-frequent classes higher, so as to prevent model output bias
# pos_weight = (num. negative samples / (num. positive samples)
pos_weight = float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()

# normalize (scale) average weighted cost
norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0] - adj.sum()) * 2)

# Create VAE model
model = GCNModelAE(placeholders, num_features, num_nodes, features_nonzero)
opt = OptimizerAE(preds=model.reconstructions,
                        labels=tf.reshape(tf.sparse_tensor_to_dense(placeholders['adj_orig'],
                                                                    validate_indices=False), [-1]),
                        pos_weight=pos_weight,
                        norm=norm,
                        learning_rate=LEARNING_RATE)
# Out:
# WARNING:tensorflow:From /Users/chengwang/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:206: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /Users/chengwang/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:206: calling weighted_cross_entropy_with_logits (from tensorflow.python.ops.nn_impl) with targets is deprecated and will be removed in a future version.
# Instructions for updating:
# targets is deprecated, use labels instead

# %%
# Calculate ROC AUC
def get_roc_score_gae(edges_pos, edges_neg, pos_weight, norm, emb=None):
    if emb is None:
        feed_dict.update({placeholders['dropout']: 0})
        emb = sess.run(model.z_mean, feed_dict=feed_dict)

    def sigmoid(x):
        return 1 / (1 + np.exp(-x))

    # Predict on test set of edges
    adj_rec = np.dot(emb, emb.T)
    preds_pos = []
    pos = []
    for e in edges_pos:
        preds_pos.append(sigmoid(adj_rec[e[0], e[1]])) # predicted score for given edge
        pos.append(adj_orig[e[0], e[1]]) # actual value (1)

    preds_neg = []
    neg = []
    for e in edges_neg:
        preds_neg.append(sigmoid(adj_rec[e[0], e[1]])) # predicted score for given edge
        neg.append(adj_orig[e[0], e[1]]) # actual value (0)

    preds_all = np.hstack([preds_pos, preds_neg])
    labels_all = np.hstack([np.ones(len(preds_pos)), np.zeros(len(preds_neg))])
    roc_score = roc_auc_score(labels_all, preds_all)
    fpr, tpr, _ = roc_curve(labels_all, preds_all)
    precision, recall, _ = precision_recall_curve(labels_all, preds_all)
    pr_score = auc(recall, precision)
    ap_score = average_precision_score(labels_all, preds_all)
    
    # val_loss = norm * tf.reduce_mean(tf.nn.weighted_cross_entropy_with_logits(labels=tf.constant(labels_all), logits=tf.constant(preds_all), pos_weight=pos_weight))
    # val_loss = tf.keras.backend.eval(val_loss)

    return roc_score, ap_score, fpr, tpr, pr_score, precision, recall

# %%
# Initialize session
sess = tf.Session()
sess.run(tf.global_variables_initializer())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d0c2a3be265d> in <module>
#       1 # Initialize session
# ----> 2 sess = tf.Session()
#       3 sess.run(tf.global_variables_initializer())
#
# NameError: name 'tf' is not defined

# %%
# Train model
for epoch in range(1):
    t = time.time()
    # Construct feed dictionary
    feed_dict = construct_feed_dict(adj_norm, adj_label, features_tuple, placeholders)
    feed_dict.update({placeholders['dropout']: DROPOUT})
    # Run single weight update
    outs = sess.run([opt.opt_op, opt.cost, opt.accuracy], feed_dict=feed_dict)

    # Compute average loss
    avg_cost = outs[1]
    avg_accuracy = outs[2]
    roc_curr, ap_curr, fpr, tpr, pr_score, precision, recall = get_roc_score_gae(train_edges, train_edges_false, pos_weight, norm)
    # train_loss_log.append(train_loss_epoch)

    # # Evaluate predictions
    roc_curr, ap_curr, fpr, tpr, pr_score, precision, recall = get_roc_score_gae(val_edges, val_edges_false, pos_weight, norm)
    val_roc_score.append(roc_curr)
    # val_loss_log.append(val_loss_epoch)
    
    if (epoch+1)%50 == 0:
    # Print results for this epoch
        print("Epoch:", '%04d' % (epoch + 1), "train_loss=", "{:.5f}".format(avg_cost),
            "train_acc=", "{:.5f}".format(avg_accuracy), "val_roc=", "{:.5f}".format(val_roc_score[-1]),
            "val_ap=", "{:.5f}".format(ap_curr),
            "time=", "{:.5f}".format(time.time() - t))

print("Optimization Finished!")
# Print final results
feature_roc_score, feature_ap_score, feature_fpr, feature_tpr, feature_pr_score, feature_prcs, feature_rcal = get_roc_score_gae(test_edges, test_edges_false, pos_weight, norm)
temp = [feature_roc_score, feature_ap_score, feature_fpr, feature_tpr, feature_pr_score, feature_prcs, feature_rcal]
print('Test ROC score: ' + str(feature_roc_score))
print('Test AP score: ' + str(feature_ap_score))
spcs_temp[seed_num] = temp
result[spcs] = spcs_temp
pickle.dump(result,open('./graph_model_gae.pkl','wb'))

# %% [markdown]
# ## Plot the AUC and PR Curve

# %%
non_graph_model = pickle.load(open('./non-graph_model.pkl','rb'))
graph_model_feats = pickle.load(open('./graph_model_vgae.pkl','rb'))
graph_model_no_feats = pickle.load(open('./graph_model_vgae_no_feats.pkl','rb'))
sage_model = pickle.load(open('./graph_model_sage.pkl','rb'))
